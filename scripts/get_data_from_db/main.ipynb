# %%
import re
import os
import sys
import csv
import json
import argparse
import psycopg2
import pandas as pd
from psycopg2 import sql
from datetime import datetime
from dotenv import load_dotenv
from psycopg2.extras import RealDictCursor
load_dotenv()
# Out:
# True

# %% [markdown]
# # Connect database

# %%
DB_HOST = os.getenv("DB_HOST", "localhost")
DB_PORT = int(os.getenv("DB_PORT", "5432"))
DB_NAME = os.getenv("DB_NAME", "postgres")
DB_USER = os.getenv("DB_USER", "")
DB_PASSWORD = os.getenv("DB_PASSWORD", "")
CONNECT_TIMEOUT = int(os.getenv("DB_CONNECT_TIMEOUT", "10"))

# %%
def get_db_connection():
    """
    Trả về psycopg2 connection sử dụng biến môi trường từ .env.
    """
    conn_kwargs = {
        "host": DB_HOST,
        "port": DB_PORT,
        "dbname": DB_NAME,
        "user": DB_USER,
        "password": DB_PASSWORD,
        "connect_timeout": CONNECT_TIMEOUT,
    }
    return psycopg2.connect(cursor_factory=RealDictCursor, **conn_kwargs)

def test_connection(sql_query: str = "SELECT now() AS now"):
    """
    Thực thi 1 câu SQL test và in kết quả.
    """
    conn = None
    try:
        conn = get_db_connection()
        with conn.cursor() as cur:
            cur.execute(sql_query)
            rows = cur.fetchall()
            print(f"✓ Query executed: {sql_query}")
            for row in rows:
                print(row)
    except Exception as e:
        print(f"DB error: {e}")
    finally:
        if conn:
            conn.close()

def list_tables():
    """Liệt kê các bảng hiện có (bỏ schema hệ thống)."""
    sql_query = """
    SELECT table_schema, table_name
    FROM information_schema.tables
    WHERE table_type='BASE TABLE'
      AND table_schema NOT IN ('pg_catalog','information_schema')
    ORDER BY table_schema, table_name;
    """
    test_connection(sql_query)

def show_table_info(table_name: str, schema: str = "public", do_count: bool = False):
    """
    In thông tin bảng:
      - columns + types
      - primary key
      - indexes
      - approx size on disk
      - optional exact row count (can be slow)
    """
    conn = None
    try:
        conn = get_db_connection()
        with conn.cursor() as cur:
            # Columns + types
            cur.execute(
                """
                SELECT column_name, data_type, is_nullable, character_maximum_length
                FROM information_schema.columns
                WHERE table_schema = %s AND table_name = %s
                ORDER BY ordinal_position;
                """,
                (schema, table_name),
            )
            cols = cur.fetchall()
            if not cols:
                print(f"Table '{schema}.{table_name}' not found or has no columns.")
                return
            print(f"\nColumns for {schema}.{table_name}:")
            for c in cols:
                print(f"  - {c['column_name']}: {c['data_type']} nullable={c['is_nullable']} max_len={c['character_maximum_length']}")

            # Primary key
            cur.execute(
                """
                SELECT kcu.column_name
                FROM information_schema.table_constraints tc
                JOIN information_schema.key_column_usage kcu
                  ON tc.constraint_name = kcu.constraint_name
                 AND tc.table_schema = kcu.table_schema
                WHERE tc.table_schema = %s
                  AND tc.table_name = %s
                  AND tc.constraint_type = 'PRIMARY KEY'
                ORDER BY kcu.ordinal_position;
                """,
                (schema, table_name),
            )
            pk = [r["column_name"] for r in cur.fetchall()]
            print(f"\nPrimary key: {pk or 'NONE'}")

            # Indexes (pg_indexes)
            cur.execute(
                """
                SELECT indexname, indexdef
                FROM pg_indexes
                WHERE schemaname = %s AND tablename = %s
                ORDER BY indexname;
                """,
                (schema, table_name),
            )
            idxs = cur.fetchall()
            print(f"\nIndexes ({len(idxs)}):")
            for i in idxs:
                print(f"  - {i['indexname']}: {i['indexdef']}")

            # Size on disk (human)
            cur.execute(
                """
                SELECT
                  pg_size_pretty(pg_total_relation_size(quote_ident(%s) || '.' || quote_ident(%s))) AS total_size,
                  pg_size_pretty(pg_relation_size(quote_ident(%s) || '.' || quote_ident(%s))) AS table_size
                """,
                (schema, table_name, schema, table_name),
            )
            size_info = cur.fetchone()
            print(f"\nSize: total={size_info['total_size']} table={size_info['table_size']}")

            # Approx row estimate from pg_class
            cur.execute(
                """
                SELECT reltuples::BIGINT AS estimate_rows
                FROM pg_class c
                JOIN pg_namespace n ON n.oid = c.relnamespace
                WHERE n.nspname = %s AND c.relname = %s;
                """,
                (schema, table_name),
            )
            est = cur.fetchone()
            print(f"Estimated rows (pg_class.reltuples): {est['estimate_rows'] if est else 'N/A'}")

            # Optional exact count (use sql module to safely format identifiers)
            if do_count:
                print("\nComputing exact COUNT(*) (may be slow)...")
                q = sql.SQL("SELECT count(*) AS exact_count FROM {}.{}").format(
                    sql.Identifier(schema), sql.Identifier(table_name)
                )
                cur.execute(q)
                cnt = cur.fetchone()
                print(f"Exact rows: {cnt['exact_count']}")
    except Exception as e:
        print(f"DB error: {e}")

# %%
list_tables()
# Out:
# ✓ Query executed:
#     SELECT table_schema, table_name
#     FROM information_schema.tables
#     WHERE table_type='BASE TABLE'
#       AND table_schema NOT IN ('pg_catalog','information_schema')
#     ORDER BY table_schema, table_name;
#
# RealDictRow([('table_schema', 'public'), ('table_name', 'Action')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Admin')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Answer')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'AnswerTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Attachment')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'AttachmentReference')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'BiometricDevice')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Category')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryOpenTime')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryOpenTimeTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'City')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Content')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentMascot')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentMascotMedia')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Gallery')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'GalleryTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Home')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'HomeTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Itinerary')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ItineraryPlace')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Notification')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'NotificationHistory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'OTP')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PhotoStory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Plan')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PlanAction')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PlanTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Poi')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiClassification')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiClean')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiPoiType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Profile')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Question')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'QuestionTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Quiz')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Review')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ReviewActions')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ReviewPhoto')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Route')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ScrapingCategory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ScrapingJob')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Transportation')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'TravelType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'User')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserAction')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserDeletionRequest')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserDevice')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItinerary')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItineraryGenerationLog')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItineraryPoi')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserPlan')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserPreferences')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'embedding')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'migrations')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'spatial_ref_sys')])

# %%
show_table_info("Poi")
# Out:
# Columns for public.Poi:
#   - id: uuid nullable=NO max_len=None
#   - created_at: timestamp without time zone nullable=NO max_len=None
#   - updatedAt: timestamp without time zone nullable=NO max_len=None
#   - deletedAt: timestamp without time zone nullable=YES max_len=None
#   - cityId: uuid nullable=NO max_len=None
#   - source: character varying nullable=NO max_len=None
#   - content: text nullable=NO max_len=None
#   - raw_data: jsonb nullable=YES max_len=None
#   - metadata: jsonb nullable=NO max_len=None
#   - placeId: character varying nullable=YES max_len=None
#   - audioUrl: character varying nullable=YES max_len=None
#   - location: USER-DEFINED nullable=YES max_len=None
#
# Primary key: NONE
#
# Indexes (1):
#   - PK_101b759c3c5200a5e040a6874a0: CREATE UNIQUE INDEX "PK_101b759c3c5200a5e040a6874a0" ON public."Poi" USING btree (id)
#
# Size: total=18 MB table=2424 kB
# Estimated rows (pg_class.reltuples): 1430

# %%
show_table_info("PoiClean")
# Out:
# Columns for public.PoiClean:
#   - id: uuid nullable=NO max_len=None
#   - created_at: timestamp without time zone nullable=NO max_len=None
#   - updatedAt: timestamp without time zone nullable=NO max_len=None
#   - deletedAt: timestamp without time zone nullable=YES max_len=None
#   - name: text nullable=NO max_len=None
#   - lat: double precision nullable=NO max_len=None
#   - address: text nullable=YES max_len=None
#   - poi_type: text nullable=YES max_len=None
#   - total_reviews: integer nullable=YES max_len=None
#   - lon: double precision nullable=NO max_len=None
#   - geom: USER-DEFINED nullable=NO max_len=None
#   - stay_time: double precision nullable=YES max_len=None
#   - avg_stars: double precision nullable=YES max_len=None
#   - normalize_stars_reviews: double precision nullable=YES max_len=None
#   - open_hours: json nullable=YES max_len=None
#   - poi_type_clean: text nullable=YES max_len=None
#   - main_subcategory: text nullable=YES max_len=None
#   - specialization: text nullable=YES max_len=None
#   - travel_type: json nullable=YES max_len=None
#   - metadata: json nullable=YES max_len=None
#
# Primary key: ['id']
#
# Indexes (1):
#   - PK_7c4fe1b3d5d29eb0b2c01753f2f: CREATE UNIQUE INDEX "PK_7c4fe1b3d5d29eb0b2c01753f2f" ON public."PoiClean" USING btree (id)
#
# Size: total=2832 kB table=2688 kB
# Estimated rows (pg_class.reltuples): 1163

# %%
# Mở connection
conn = get_db_connection()
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM "PoiClean"')
rows = cur.fetchall()
for poi in rows[:5]:
    print(poi)
# Out:
# RealDictRow([('id', '0f9d2009-9436-46a4-b354-b0261898a39e'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 26, 10, 30, 11, 886556)), ('deletedAt', None), ('name', 'The Pub Coffee - Beer & Cocktail'), ('lat', 10.8294811), ('address', '18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thành phố Hồ Chí Minh, Vietnam'), ('poi_type', 'Cafe,Bar'), ('total_reviews', 181), ('lon', 106.7737852), ('geom', '0101000020E61000003F085CB285B15A40DB4C2ABFB1A82540'), ('stay_time', 25.0), ('avg_stars', 4.9), ('normalize_stars_reviews', 0.755), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Tuesday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Wednesday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Thursday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Friday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Saturday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Sunday', 'hours': [{'start': '00:00', 'end': '23:59'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Live Music Venue'), ('specialization', 'Live Entertainment'), ('travel_type', {'Solo': 25, 'Couple': 40, 'Friends': 80, 'Family with kids': 10, 'Business traveler / free time': 30}), ('metadata', {'additionalInfo': {'Crowd': [{'Groups': True}], 'Payments': [{'NFC mobile payments': True}], 'Planning': [{'Accepts reservations': True}], 'Amenities': [{'Bar onsite': True}, {'Restroom': True}], 'Offerings': [{'Alcohol': True}, {'Beer': True}, {'Cocktails': True}, {'Coffee': True}, {'Hard liquor': True}], 'Atmosphere': [{'Casual': True}, {'Cozy': True}], 'Highlights': [{'Great beer selection': True}, {'Great coffee': True}, {'Live music': True}, {'Live performances': True}], 'Dining options': [{'Table service': True}], 'Service options': [{'No-contact delivery': True}, {'Delivery': True}, {'Drive-through': True}, {'Takeout': True}, {'Dine-in': True}]}})])
# RealDictRow([('id', '622c7643-30e8-4402-9b6c-b8407ff063e2'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 26, 10, 30, 11, 886556)), ('deletedAt', None), ('name', 'BAIETA Restaurant Saigon Thao Dien'), ('lat', 10.802978), ('address', 'Nguyễn Văn Hưởng, Thảo Điền, 16/8, Thành phố Hồ Chí Minh 700000, Vietnam'), ('poi_type', 'Restaurant,Bar,Cocktail bar,Coffee shop,Family restaurant,Mediterranean restaurant'), ('total_reviews', 285), ('lon', 106.727268), ('geom', '0101000020E610000059DB148F8BAE5A40A2D0B2EE1F9B2540'), ('stay_time', 70.0), ('avg_stars', 4.5), ('normalize_stars_reviews', 0.651), ('open_hours', [{'day': 'Tuesday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Thursday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Friday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Saturday', 'hours': [{'start': '11:30', 'end': '00:00'}]}, {'day': 'Sunday', 'hours': [{'start': '11:30', 'end': '00:00'}]}]), ('poi_type_clean', 'Restaurant'), ('main_subcategory', 'Family Restaurant'), ('specialization', None), ('travel_type', {'Solo': 60, 'Couple': 70, 'Friends': 75, 'Family with kids': 80, 'Business traveler / free time': 50}), ('metadata', {'additionalInfo': {'Pets': [{'Dogs allowed': True}], 'Crowd': [{'Family-friendly': True}, {'Groups': True}, {'LGBTQ+ friendly': True}, {'Tourists': True}], 'Parking': [{'Free parking lot': True}, {'Free street parking': True}, {'Usually plenty of parking': True}], 'Children': [{'Good for kids': True}], 'Payments': [{'Credit cards': True}, {'Debit cards': True}], 'Planning': [{'Dinner reservations recommended': True}, {'Accepts reservations': True}], 'Amenities': [{'Bar onsite': True}, {'Restroom': True}], 'Offerings': [{'Alcohol': True}, {'Beer': True}, {'Cocktails': True}, {'Coffee': True}, {'Happy hour drinks': True}, {'Hard liquor': True}, {'Small plates': True}, {'Vegetarian options': True}, {'Wine': True}], 'Atmosphere': [{'Casual': True}, {'Cozy': True}, {'Romantic': True}], 'Highlights': [{'Great beer selection': True}, {'Great cocktails': True}, {'Great coffee': True}, {'Great dessert': True}, {'Great wine list': True}, {'Rooftop seating': True}], 'Popular for': [{'Lunch': True}, {'Dinner': True}, {'Solo dining': True}], 'Accessibility': [{'Wheelchair accessible seating': True}], 'Dining options': [{'Brunch': True}, {'Lunch': True}, {'Dinner': True}, {'Catering': True}, {'Counter service': True}, {'Dessert': True}, {'Seating': True}, {'Table service': True}], 'Service options': [{'Outdoor seating': True}, {'Takeout': True}, {'Dine-in': True}]}})])
# RealDictRow([('id', '4f06908d-e9fa-4f6a-b1ae-c7d8882e2edf'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 26, 10, 30, 11, 886556)), ('deletedAt', None), ('name', 'Parroquia San Felipe Neri'), ('lat', 36.7255541), ('address', 'C. Guerrero, 6, Distrito Centro, 29012 Málaga, Spain'), ('poi_type', 'Catholic church,Tourist attraction'), ('total_reviews', 329), ('lon', -4.4213208), ('geom', '0101000020E61000008C7F44B86EAF11C0467DEDF4DE5C4240'), ('stay_time', 22.0), ('avg_stars', 4.7), ('normalize_stars_reviews', 0.716), ('open_hours', [{'day': 'Tuesday', 'hours': [{'start': '17:30', 'end': '20:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '17:30', 'end': '20:00'}]}, {'day': 'Thursday', 'hours': [{'start': '17:30', 'end': '20:00'}]}, {'day': 'Friday', 'hours': [{'start': '17:30', 'end': '20:00'}]}, {'day': 'Saturday', 'hours': [{'start': '17:30', 'end': '20:00'}]}, {'day': 'Sunday', 'hours': [{'start': '09:00', 'end': '13:00'}]}]), ('poi_type_clean', 'Catholic church'), ('main_subcategory', None), ('specialization', None), ('travel_type', {'Solo': 40, 'Couple': 50, 'Friends': 30, 'Family with kids': 60, 'Business traveler / free time': 20}), ('metadata', {'additionalInfo': {'Accessibility': [{'Wheelchair accessible entrance': True}]}})])
# RealDictRow([('id', '279dfce3-c227-4b58-b4ed-09197327a32a'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 26, 10, 30, 11, 886556)), ('deletedAt', None), ('name', 'BÀ BAR'), ('lat', 10.8031895), ('address', '15 Đ. Nguyễn Cừ, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh 70000, Vietnam'), ('poi_type', 'Cocktail bar,Cafe'), ('total_reviews', 182), ('lon', 106.7283812), ('geom', '0101000020E61000005C412ECC9DAE5A402FFB75A73B9B2540'), ('stay_time', 100.0), ('avg_stars', 4.8), ('normalize_stars_reviews', 0.725), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '10:00', 'end': '00:00'}]}, {'day': 'Tuesday', 'hours': [{'start': '10:00', 'end': '00:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '10:00', 'end': '00:00'}]}, {'day': 'Thursday', 'hours': [{'start': '10:00', 'end': '00:00'}]}, {'day': 'Friday', 'hours': [{'start': '10:00', 'end': '00:00'}]}, {'day': 'Saturday', 'hours': [{'start': '08:00', 'end': '00:00'}]}, {'day': 'Sunday', 'hours': [{'start': '08:00', 'end': '00:00'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Live Music Venue'), ('specialization', 'Live Entertainment'), ('travel_type', {'Solo': 30, 'Couple': 50, 'Friends': 80, 'Family with kids': 10, 'Business traveler / free time': 25}), ('metadata', {'additionalInfo': {'Pets': [{'Dogs allowed': True}], 'Crowd': [{'Groups': True}, {'LGBTQ+ friendly': True}, {'Transgender safespace': True}], 'Parking': [{'Valet parking': True}], 'Payments': [{'Credit cards': True}, {'Debit cards': True}, {'NFC mobile payments': True}], 'Planning': [{'Accepts reservations': True}], 'Amenities': [{'Gender-neutral restroom': True}, {'Restroom': True}, {'Wi-Fi': True}, {'Free Wi-Fi': True}], 'Offerings': [{'Alcohol': True}, {'Beer': True}, {'Cocktails': True}, {'Food': True}, {'Happy hour drinks': True}, {'Happy hour food': True}, {'Hard liquor': True}, {'Wine': True}], 'Atmosphere': [{'Casual': True}], 'Highlights': [{'Live music': True}, {'Live performances': True}], 'Dining options': [{'Seating': True}, {'Table service': True}], 'Service options': [{'Outdoor seating': True}, {'No-contact delivery': True}, {'Delivery': True}, {'Drive-through': True}, {'Onsite services': True}, {'Takeout': True}, {'Dine-in': True}], 'From the business': [{'Identifies as women-owned': True}]}})])
# RealDictRow([('id', '1d66bcc3-7f32-42b6-8880-236437496c89'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 26, 10, 30, 11, 886556)), ('deletedAt', None), ('name', 'Art Bar Viet Nam'), ('lat', 10.8039632), ('address', '29 Nguyễn Bá Huân, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh, Vietnam'), ('poi_type', 'Bar,Art gallery,Cocktail bar'), ('total_reviews', 165), ('lon', 106.7290573), ('geom', '0101000020E61000003E1AF3DFA8AE5A4001608610A19B2540'), ('stay_time', 100.0), ('avg_stars', 4.9), ('normalize_stars_reviews', 0.752), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '16:00', 'end': '00:00'}]}, {'day': 'Tuesday', 'hours': [{'start': '16:00', 'end': '00:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '16:00', 'end': '00:00'}]}, {'day': 'Thursday', 'hours': [{'start': '16:00', 'end': '00:00'}]}, {'day': 'Friday', 'hours': [{'start': '16:00', 'end': '00:00'}]}, {'day': 'Saturday', 'hours': [{'start': '16:00', 'end': '00:00'}]}, {'day': 'Sunday', 'hours': [{'start': '16:00', 'end': '00:00'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Live Music Venue'), ('specialization', 'Live Entertainment'), ('travel_type', {'Solo': 30, 'Couple': 50, 'Friends': 80, 'Family with kids': 10, 'Business traveler / free time': 25}), ('metadata', {'additionalInfo': {'Pets': [{'Dogs allowed': True}], 'Crowd': [{'Groups': True}, {'LGBTQ+ friendly': True}, {'Tourists': True}, {'Transgender safespace': True}], 'Parking': [{'Free parking lot': True}, {'Free street parking': True}, {'Valet parking': True}], 'Payments': [{'Credit cards': True}, {'Debit cards': True}, {'Credit cards': True}], 'Planning': [{'Accepts reservations': True}], 'Amenities': [{'Restroom': True}, {'Wi-Fi': True}, {'Free Wi-Fi': True}], 'Offerings': [{'Alcohol': True}, {'Cocktails': True}, {'Food': True}, {'Food at bar': True}, {'Hard liquor': True}, {'Wine': True}], 'Atmosphere': [{'Cozy': True}], 'Highlights': [{'Bar games': True}, {'Great cocktails': True}, {'Live performances': True}], 'Accessibility': [{'Wheelchair accessible entrance': True}, {'Wheelchair accessible parking lot': True}, {'Wheelchair accessible seating': True}, {'Assistive hearing loop': False}], 'Dining options': [{'Seating': True}, {'Table service': True}], 'Service options': [{'Takeout': True}, {'Dine-in': True}, {'Delivery': False}]}})])

# %%
cur.execute('SELECT * FROM "Poi"')
rows = cur.fetchall()
for poi in rows[:5]:
    print(poi)

# %% [markdown]
# # Các feature cần phải lấy ra từ table Poi
#
# - id UUID PRIMARY KEY, lấy từ cột id
# - name TEXT NOT NULL, lấy từ cột content
# - address TEXT, lấy từ cột content
# - lat DOUBLE PRECISION NOT NULL, lấy từ cột content
# - lon DOUBLE PRECISION NOT NULL, lấy từ cột content
# - geom GEOMETRY(Point, 4326) NOT NULL, tạo ra code
# - poi_type TEXT, lấy từ cột content
# - stay_time DOUBLE PRECISION CHECK (stay_time >= 0), default 30
# - opening_hours lấy từ cột raw_data
# - crowd, children, offerings, atmosphere, highlights, popular_for, dining_options, accessibility options lấy từ metadata.additionalInfo
# - avg_stars DOUBLE PRECISION CHECK (avg_stars BETWEEN 0 AND 5), lấy từ cột raw_data
# - total_reviews INTEGER CHECK (total_reviews >= 0), từ cột raw_data
# - normalize_stars_reviews DOUBLE PRECISION # normalize avg_stars và total_reviews về thang điểm 0-1

# %% [markdown]
# # Tạo 1 file csv

# %%
file_path = os.path.join(os.getcwd(), "../data_csv/data.csv")
print(f"File path: {file_path}")

# Tạo thư mục nếu chưa tồn tại
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# Tạo file nếu chưa tồn tại
if not os.path.exists(file_path):
    with open(file_path, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)

# Đọc dữ liệu
if not os.path.exists(file_path) or os.stat(file_path).st_size == 0:
    df = pd.DataFrame()   # df rỗng, chưa có cột
else:
    df = pd.read_csv(file_path)

print(df)
# Out:
# File path: c:\Users\nguye\Desktop\vinamo\Main_Branch\Kyanon-support-localtion\scripts\get_data_from_db\../data/data.csv
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Trích xuất các trường

# %%
def extract_true_keys(items):
    """
    Trả về danh sách các key có giá trị True trong một list các dictionary.

    Ví dụ:
        items = [{"Wifi": True, "Outdoor seating": False}]
        → ["Wifi"]

    - Nếu items không phải list → trả về []
    - Mỗi phần tử trong items phải là dict thì mới xét
    """
    if not isinstance(items, list):
        return []
    return [
        key
        for d in items if isinstance(d, dict)
        for key, value in d.items()
        if value is True
    ]


def clean_opening_hours(data):
    """
    Làm sạch dữ liệu ngày & giờ từ Google.

    Nhiệm vụ:
    - Thay ký tự \u202f (narrow no-break space) bằng space bình thường " "
    - Giữ nguyên cấu trúc và nội dung ngày/giờ
    - Trả về danh sách cùng số lượng phần tử như input

    Input mẫu:
        [
            [{"day": "Monday", "hours": "10 AM to 5 PM"}],
            [{"day": "Tuesday", "hours": "Closed"}]
        ]

    Output:
        [
            [{"day": "Monday", "hours": "10 AM to 5 PM"}],
            [{"day": "Tuesday", "hours": "Closed"}]
        ]
    """
    cleaned = []
    for items in data:
        cleaned_items = []
        for i in items:
            cleaned_items.append({
                "day": i["day"],
                "hours": i["hours"].replace("\u202f", " ")
            })
        cleaned.append(cleaned_items)
    return cleaned

# ---- Helper: convert time string to 24h format ----
def to_24h(time_str, fallback_am_pm=None):
    time_str = time_str.strip()

    # If contains AM/PM → direct parse
    if "AM" in time_str.upper() or "PM" in time_str.upper():
        return datetime.strptime(time_str.upper(), "%I:%M %p").strftime("%H:%M") \
            if ":" in time_str else datetime.strptime(time_str.upper(), "%I %p").strftime("%H:%M")

    # If missing AM/PM, but fallback exists
    if fallback_am_pm:
        combined = f"{time_str} {fallback_am_pm}"
        try:
            return datetime.strptime(combined, "%I:%M %p").strftime("%H:%M") \
                if ":" in time_str else datetime.strptime(combined, "%I %p").strftime("%H:%M")
        except:
            pass

    # If totally unknown → assume 24h? But better skip
    return None


# ---- Main parser for hours ----
def parse_hours(hours_str):
    hours_str = hours_str.replace("\u202f", " ").strip()

    # Closed → skip
    if hours_str.lower() == "closed":
        return []

    # Open 24 hours
    if "open 24 hours" in hours_str.lower():
        return [{"start": "00:00", "end": "23:59"}]

    segments = [seg.strip() for seg in hours_str.split(",")]
    results = []

    for segment in segments:
        # Example segment: "1:30 to 4 PM"
        match = re.match(r"(.*) to (.*)", segment)
        if not match:
            continue

        start_raw, end_raw = match.groups()
        start_raw = start_raw.strip()
        end_raw = end_raw.strip()

        # Determine fallback AM/PM from end if start lacks AM/PM
        fallback = None
        if "AM" in end_raw.upper():
            fallback = "AM"
        if "PM" in end_raw.upper():
            fallback = "PM"

        start_24 = to_24h(start_raw, fallback)
        end_24 = to_24h(end_raw)

        if start_24 and end_24:
            results.append({
                "start": start_24,
                "end": end_24
            })

    return results


# ---- Main function to process full opening_hours array ----
def normalize_opening_hours(opening_hours):
    normalized = []

    for item in opening_hours:
        day = item["day"]
        hours = parse_hours(item["hours"])

        if hours:  # Skip closed days
            normalized.append({"day": day, "hours": hours})

    return normalized

def clean_opening_hours_special(data):
    cleaned_special = []
    for d in data:
        if len(d) == 0:
            cleaned_special.append([])
        else:
            item = normalize_opening_hours(d)
            cleaned_special.append(item)
    return cleaned_special

# %%
cur.execute('SELECT id, content, raw_data, metadata FROM "Poi"')
rows = cur.fetchall()

for row in rows[:5]:
    print(row)
# Out:
# RealDictRow([('id', '0f9d2009-9436-46a4-b354-b0261898a39e'), ('content', '{"name":"The Pub Coffee - Beer & Cocktail","placeId":"ChIJ7R9GGLQndTERJRircGTWzn4","description":"","lat":10.8294811,"long":106.7737852,"type":["Cafe","Bar"],"address":"18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thành phố Hồ Chí Minh, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/0d6d8596-ded7-4e10-954b-096aa2783725.jpg","photoUrls":["pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/0d6d8596-ded7-4e10-954b-096aa2783725.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/5f9da691-9b82-4ff2-86ea-7316f6f34028.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/7b15a9c4-8981-4255-be10-bd193951b4e2.jpg","pois/images/ChI
","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/175f30a2-4863-4bf7-960b-f10e70931a1e.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/3acaaa45-f090-47ad-a713-33a520d4f94b.jpg"],"description":"Nestled in the heart of Málaga, Julieta is a charming café located at C. Sta. Lucía, 9, in the vibrant Distrito Centro. This delightful spot offers a warm, inviting atmosphere, perfect for sipping coffee while soaking in the local culture. With its rustic decor and friendly staff, Julieta serves a delectable array of pastries and traditional Spanish snacks, making it an ideal stop for breakfast or an afternoon treat. The café’s rich history and connection to the community add to its allure, inviting visitors to relax and enjoy the lively ambiance. Come experience the heart of Málaga at Julieta!"}'), ('raw_data', {'google': {'cid': '1032288182745415370', 'fid': '0xd72f7be216c0001:0xe536ca2065fbeca', 'url': 'https://www.google.com/maps/search/?api=1&query=Julieta&query_place_id=ChIJAQBsIb73cg0Ryr5fBqJsUw4', 'city': 'Málaga', 'menu': None, 'rank': 16, 'kgmid': '/g/11hcj3lxdk', 'phone': '+34 681 39 79 16', 'price': '€1–10', 'state': 'Málaga', 'title': 'Julieta', 'images': None, 'street': 'C. Sta. Lucía, 9', 'address': 'C. Sta. Lucía, 9, Distrito Centro, 29008 Málaga, Spain', 'orderBy': [{'name': 'Glovo', 'orderUrl': 'https://glovoapp.com/es/es/malaga/la-bella-julieta-malaga?utm_source=google&utm_medium=organic&utm_campaign=google_reserve_place_order_action'}, {'name': 'UberEats', 'orderUrl': 'https://www.ubereats.com/es/store/la-bella-julieta-santa-lucia/SOQMedOTXn2tskLdNumrhQ?utm_campaign=CM2508147-search-free-nonbrand-google-pas_e_all_acq_Global&utm_medium=search-free-nonbrand&utm_source=google-pas'}], 'placeId': 'ChIJAQBsIb73cg0Ryr5fBqJsUw4', 'reviews': [{'name': 'Arturas Karasiovas (Arturas Karasiovas)', 'text': 'We had a very delicious breakfast. However, the only downside was that, since we were sitting outside, the staff didn’t inform us that we needed to place our order inside, so we ended up waiting for a while. That said, the staff at the payment counter were very friendly, especially the guy who served us. The food was delivered very quickly!\n\nMuchos gracias ! :)', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2pjdGVWbHFURzFOYkVKelozQkZTVEpSTmpGd2NHYxAB', 'publishAt': 'a month ago', 'reviewUrl': 'https://www.google.com/maps/revie ...
# RealDictRow([('id', '622c7643-30e8-4402-9b6c-b8407ff063e2'), ('content', '{"name":"BAIETA Restaurant Saigon Thao Dien","placeId":"ChIJRf35mx8ndTERFDWKEtT8BHQ","description":"","lat":10.802978,"long":106.727268,"type":["Restaurant","Bar","Cocktail bar","Coffee shop","Family restaurant","Mediterranean restaurant"],"address":"Nguyễn Văn Hưởng, Thảo Điền, 16/8, Thành phố Hồ Chí Minh 700000, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/13d7f738-b6fb-41e5-ba7e-36748f8f1632.jpg","photoUrls":["p
 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2paVGEwNXZURU4wUVVSa1ZHSkJVWEV4TkdvMmNFRRAB!2m1!1s0x0:0x7404fcd4128a3514!3m1!1s2@1:CAIQACodChtycF9oOjZTa05vTEN0QURkVGJBUXExNGo2cEE%7C0dBrp3imk1s%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '113496947416193187862', 'reviewerUrl': 'https://www.google.com/maps/contrib/113496947416193187862?hl=en', 'isLocalGuide': True, 'reviewOrigin': 'Google', 'reviewContext': {'Meal type': 'Dinner', 'Group size': '2 people, 3-4 people', 'Noise level': 'Moderate noise', 'Price per person': '₫700–800K'}, 'textTranslated': 'The atmosphere is crazy!!\nAll the staff speak English well and are very friendly.\n\nI went there around 5pm, and it was so beautiful👍\n\nThe food and drinks are on the pricey side, and the portions are small, but the view makes up for it!\nReservations are required starting Friday night.', 'publishedAtDate': '2025-12-06T00:48:04.785Z', 'reviewImageUrls': ['https://lh3.googleusercontent.com/geougc-cs/AMBA38sRzU2EURNaRMZwrs5c3Y2c4E28CMdXXTIP4qvmbj6YrXBpPyTlkjWktzqSl1U-CthNZQ6C30UQqmRU_quAE0jO0iXJjOkh-M2dSrVOAAWa0BDb1WCUpDMd6zHQa8yZvE2RowaHn5tSPHw', 'https://lh3.googleusercontent.com/geougc-cs/AMBA38uoWyhaFQSYrYJuMt2X-kj7LZZjWVF2uFU9SrQ-H9XX77IVXH_aYPPXP3hhZ5FZlnJ5yJa94dE77IXlcR3GsMHAypvWledrt26eUm_jteJHa-x5mSgeWBclsI1KdFJvEEhx3yAeysPzx4vD', 'https://lh3.googleusercontent.com/geougc-cs/AMBA38vNtDpTMhOgGnkhsHsoV2n ...
# RealDictRow([('id', '4f06908d-e9fa-4f6a-b1ae-c7d8882e2edf'), ('content', '{"lat":36.7255541,"city":"Málaga","long":-4.4213208,"name":"Parroquia San Felipe Neri","type":["Catholic church","Tourist attraction"],"story":"Welcome to the Parroquia San Felipe Neri, a hidden gem in Málaga! This charming Baroque church, built in the 18th century, boasts stunning frescoes and a serene atmosphere. Fun fact: it was named after the beloved saint known for his playful spirit and love for children! Visitors on Instagram often rave about its tranquil ambiance, with many snapping photos of its ornate altar and peaceful courtyard. If you’re lucky, you might catch a glimpse of a local wedding, which has become a trending moment on TikTok. So, take a seat, listen to the whispers of history, and soak in the beauty of San Felipe Neri!","address":"C. Guerrero, 6, Distrito Centro, 29012 Málaga, Spain","placeId":"ChIJEfbQ6L73cg0RiM3qIjLLsmk","imageUrl":"pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/269b781f-6532-45b3-89a3-9fd44ef0c0c9.jpg","photoUrls":["pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/269b781f-6532-45b3-89a3-9fd44ef0c0c9.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/8818118a-cc76-4468-ba56-49ae2e60c329.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/168acc07-124a-4e3d-b7f8-bd198a6e3471.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/ef94bf03-4ec6-4038-8187-ddf87aafe177.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/d0f6a664-cbe6-4d49-ba13-36dfc303780b.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/66552a48-034a-46cd-8514-b2ca4ad258c3.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/1717ced5-a733-4af5-b6dd-415e9dfb327d.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/a30f13b1-58c1-4a92-8945-ac3edbf0bbea.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/93fbad53-ff50-43b4-9e23-7b87be080974.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/bc49fb6d-3af0-4578-be26-01b3befdde39.jpg"],"description":"Nestled in the heart of Málaga, the Parroquia San Felipe Neri is a stunning example of Baroque architecture that invites visitors to explore its rich history. Located at C. Guerrero, 6, this charming Catholic church boasts intricate altarpieces and a serene atmosphere, making it a perfect spot for reflection. As you step inside, the soft glow of sunlight filtering through stained glass illuminates the beautifully adorned interior, creating a peaceful ambiance. This hidden gem not only serves as a place of worship but also as a cultural landmark, reflecting the city\'s artistic heritage. Don’t miss the chance to discover this tranquil oasis in bustling Málaga!"}'), ('raw_data', {'google': {'cid': '7616373336031546760', 'fid': '0xd72f7bee8d0f611:0x69b2cb3222eacd88', 'url': 'https://www.google.com/maps/search/?api=1&query=Parroquia%20San%20Felipe%20Neri&query_place_id=ChIJEfbQ6L73cg0RiM3qIjLLsmk', 'city': 'Málaga', 'menu': None, 'rank': 19, 'kgmid': '/g/122fpsn6', 'phone': '+34 952 21 16 07', 'price': None, 'state': 'Málaga', 'title': 'Parroquia San Felipe Neri', 'images': None, 'street': 'C. Guerrero, 6', 'address': 'C. Guerrero, 6, Distrito Centro, 29012 Málaga, Spain', 'orderBy': [], 'placeId': 'ChIJEfbQ6L73cg0RiM3qIjLLsmk', 'reviews': [{'name': 'David Phipps', 'text': 'Worth a quick stop to look', 'stars': 5, 'rating': None, 'reviewId': 'ChZDSUhNMG9nS0VJQ0FnSUNtMG9UX0xBEAE', 'publishAt': '3 years ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNtMG9UX0xBEAE!2m1!1s0x0:0x69b2cb3222eacd88!3m1!1s2@1:CIHM0ogKEICAgICm0oT_LA%7C%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '101097237930536668213', 'reviewerUrl': 'https://www.google.com/maps/contrib/101097237930536668213?hl=en', 'isLocalGuide': True, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': None, 'publishedAtDate': '2021-12-23T19:04:36.342Z', 'reviewImageUrls': ['https://lh3.googleusercontent.com/geougc-cs/AB3l90D-A2-PvfVjcvjL_EQsinKlOWzhfR1aVlp2ARR2fmi3XY4VCyTGVfgB0Uf_OR8SFYGT5Rpryjexv9C4HKkKGi3_ftTx9zT7EpqtfPV9zz7KQbcndZkobqlfXKLhXgHJ2hZcFck ...
 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xoRVMzRTFNbGs1ZDFCeFgwRjBZMFpxTmw5SlVIYxAB!2m1!1s0x0:0x3571b60d02fd12af!3m1!1s2@1:CAIQACodChtycF9oOlhES3E1Mlk5d1BxX0F0Y0ZqNl9JUHc%7C0dB4dt6bz7I%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '110868685349360257722', 'reviewerUrl': 'https://www.google.com/maps/contrib/110868685349360257722?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': 'Fun shop, ok drinks. Fun Wednesday night', 'publishedAtDate': '2025-12-03T15:42:49.127Z', 'reviewImageUrls': [], 'originalLanguage': 'vi', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a-/ALV-UjUmKutt-TylIRo6mNBbUcHt74yHLcew9tjKJHx43eQ8a7bb2mFS_A=s1920-c-rp-mo-br100', 'translatedLanguage': 'en', 'reviewDetailedRating': {}, 'responseFromOwnerDate': '2025-12-04T09:43:34.000Z', 'responseFromOwnerText': 'Dạ cảm ơn chị nhiều ạ', 'reviewerNumberOfReviews': 4}, {'name': 'Xuan Nam', 'text': 'nhà nhỏ xíu, phía trước là ngoài trời, trong nhà có máy lạnh mà tối, sida', 'stars': 2, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2pSVmJVcEVjMGRTVjJOc1dGVlBSVlF4YWpoQ2NFRRAB', 'publishAt': '2 days ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2pSVmJVcEVjMGRTVjJOc1dGVlBSVlF4YWpoQ2NFRRAB!2m1!1s0x0:0x3571b60d02fd12af!3m1!1s2@1:CAIQACodChtycF9oOjRVbUpEc0dSV2NsWFVPRVQxajhCcEE%7C0dAuZNRpmGn%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '108483542791555855381', 'reviewerUrl': 'https://www.google.com/maps/contrib/108483542791555855381?hl=en', 'isLocalGuide': True, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': 'tiny house, the front is open air, the inside has air conditioning but is dark, AIDS', 'publishedAtDate ...

# %%
# Khởi tạo list cho từng cột
ids = []
names = []
addresses = []
lats = []
lons = []
poi_types = []
avg_stars = []
total_reviews = []

crowd = []
offerings = []
atmosphere = []
highlights = []
dining_options = []
children = []
accessibility = []
popular_for = []

opening_hours_raw = []

# ---- Xử lý toàn bộ trong 1 vòng lặp ----
for poi in rows:

    # -------------------- id --------------------
    ids.append(poi.get("id"))

    # -------------------- content --------------------
    raw = poi.get("content")
    if isinstance(raw, str):
        try:
            content = json.loads(raw)
        except:
            content = {}
    else:
        content = {}

    names.append(content.get("name"))
    addresses.append(content.get("address"))
    lats.append(content.get("lat"))
    lons.append(content.get("long"))

    # Type có thể là list hoặc string
    types = content.get("type")
    if isinstance(types, list):
        poi_types.append(",".join(types))
    else:
        poi_types.append(types)

    # -------------------- raw_data --------------------
    raw_data = poi.get("raw_data") or {}
    google = raw_data.get("google") or {}

    avg_stars.append(google.get("totalScore"))
    total_reviews.append(google.get("reviewsCount"))

    # opening_hours
    opening_hours_raw.append(google.get("openingHours"))

    # -------------------- metadata --------------------
    metadata = poi.get("metadata") or {}
    additional = metadata.get("additionalInfo") or {}

    crowd.append(extract_true_keys(additional.get("Crowd")))
    offerings.append(extract_true_keys(additional.get("Offerings")))
    atmosphere.append(extract_true_keys(additional.get("Atmosphere")))
    highlights.append(extract_true_keys(additional.get("Highlights")))
    dining_options.append(extract_true_keys(additional.get("Dining options")))
    children.append(extract_true_keys(additional.get("Children")))
    accessibility.append(extract_true_keys(additional.get("Accessibility")))
    popular_for.append(extract_true_keys(additional.get("Popular for")))

# -------------------- Fill vào DataFrame --------------------
df["id"] = ids
df["name"] = names
df["address"] = addresses
df["lat"] = lats
df["lon"] = lons
df["poi_type"] = poi_types

df["avg_stars"] = avg_stars
df["total_reviews"] = total_reviews

df["crowd"] = [", ".join(x) for x in crowd]
df["offerings"] = [", ".join(x) for x in offerings]
df["atmosphere"] = [", ".join(x) for x in atmosphere]
df["highlights"] = [", ".join(x) for x in highlights]
df["dining_options"] = [", ".join(x) for x in dining_options]
df["children"] = [", ".join(x) for x in children]
df["accessibility"] = [", ".join(x) for x in accessibility]
df["popular_for"] = [", ".join(x) for x in popular_for]

# -------------------- opening hours --------------------
result = clean_opening_hours(opening_hours_raw)
df["opening_hours"] = clean_opening_hours_special(result)

# %%
df.shape
# Out:
# (1454, 17)

# %%
df.head(2)
# Out:
#                                      id                              name  \
# 0  0f9d2009-9436-46a4-b354-b0261898a39e  The Pub Coffee - Beer & Cocktail
# 1  02887955-963a-43ac-b0f7-355d7d7cfacf                           Julieta
#
#                                              address        lat         lon  \
# 0  18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thà...  10.829481  106.773785
# 1  C. Sta. Lucía, 9, Distrito Centro, 29008 Málag...  36.722011   -4.421780
#
#    poi_type avg_stars total_reviews                               crowd  \
# 0  Cafe,Bar       4.9           181                              Groups
# 1      Cafe       4.3          2053  College students, Groups, Tourists
#
#                                            offerings            atmosphere  \
# 0      Alcohol, Beer, Cocktails, Coffee, Hard liquor          Casual, Cozy
# 1  Alcohol, Beer, Coffee, Healthy options, Organi...  Casual, Cozy, Trendy
#
#                                           highlights  \
# 0  Great beer selection, Great coffee, Live music...
# 1   Great coffee, Great dessert, Great tea selection
#
#                                       dining_options       children  \
# 0                                      Table service
# 1  Breakfast, Brunch, Lunch, Dessert, Seating, Ta...  Good for kids
#
#                                        accessibility  \
# 0
# 1  Wheelchair accessible entrance, Wheelchair acc...
#
#                              popular_for  \
# 0
# 1  Breakfast, Good for working on laptop
#
#                                        opening_hours
# 0  [{'day': 'Monday', 'hours': [{'start': '00:00'...
# 1  [{'day': 'Monday', 'hours': [{'start': '08:00'...

# %% [markdown]
# # Xuất vào csv

# %%
df.to_csv(file_path, index=False)
