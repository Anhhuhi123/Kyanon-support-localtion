# %%
import re
import os
import sys
import csv
import json
import argparse
import psycopg2
import pandas as pd
from psycopg2 import sql
from datetime import datetime
from dotenv import load_dotenv
from psycopg2.extras import RealDictCursor, execute_batch
load_dotenv()
# Out:
# True

# %% [markdown]
# # Connect database

# %%
DB_HOST = os.getenv("DB_HOST", "localhost")
DB_PORT = int(os.getenv("DB_PORT", "5432"))
DB_NAME = os.getenv("DB_NAME", "postgres")
DB_USER = os.getenv("DB_USER", "")
DB_PASSWORD = os.getenv("DB_PASSWORD", "")
CONNECT_TIMEOUT = int(os.getenv("DB_CONNECT_TIMEOUT", "10"))

# %%
def get_db_connection():
    """
    Trả về psycopg2 connection sử dụng biến môi trường từ .env.
    """
    conn_kwargs = {
        "host": DB_HOST,
        "port": DB_PORT,
        "dbname": DB_NAME,
        "user": DB_USER,
        "password": DB_PASSWORD,
        "connect_timeout": CONNECT_TIMEOUT,
    }
    return psycopg2.connect(cursor_factory=RealDictCursor, **conn_kwargs)

def test_connection(sql_query: str = "SELECT now() AS now"):
    """
    Thực thi 1 câu SQL test và in kết quả.
    """
    conn = None
    try:
        conn = get_db_connection()
        with conn.cursor() as cur:
            cur.execute(sql_query)
            rows = cur.fetchall()
            print(f"✓ Query executed: {sql_query}")
            for row in rows:
                print(row)
    except Exception as e:
        print(f"DB error: {e}")
    finally:
        if conn:
            conn.close()

def list_tables():
    """Liệt kê các bảng hiện có (bỏ schema hệ thống)."""
    sql_query = """
    SELECT table_schema, table_name
    FROM information_schema.tables
    WHERE table_type='BASE TABLE'
      AND table_schema NOT IN ('pg_catalog','information_schema')
    ORDER BY table_schema, table_name;
    """
    test_connection(sql_query)

def show_table_info(table_name: str, schema: str = "public", do_count: bool = False):
    """
    In thông tin bảng:
      - columns + types
      - primary key
      - indexes
      - approx size on disk
      - optional exact row count (can be slow)
    """
    conn = None
    try:
        conn = get_db_connection()
        with conn.cursor() as cur:
            # Columns + types
            cur.execute(
                """
                SELECT column_name, data_type, is_nullable, character_maximum_length
                FROM information_schema.columns
                WHERE table_schema = %s AND table_name = %s
                ORDER BY ordinal_position;
                """,
                (schema, table_name),
            )
            cols = cur.fetchall()
            if not cols:
                print(f"Table '{schema}.{table_name}' not found or has no columns.")
                return
            print(f"\nColumns for {schema}.{table_name}:")
            for c in cols:
                print(f"  - {c['column_name']}: {c['data_type']} nullable={c['is_nullable']} max_len={c['character_maximum_length']}")

            # Primary key
            cur.execute(
                """
                SELECT kcu.column_name
                FROM information_schema.table_constraints tc
                JOIN information_schema.key_column_usage kcu
                  ON tc.constraint_name = kcu.constraint_name
                 AND tc.table_schema = kcu.table_schema
                WHERE tc.table_schema = %s
                  AND tc.table_name = %s
                  AND tc.constraint_type = 'PRIMARY KEY'
                ORDER BY kcu.ordinal_position;
                """,
                (schema, table_name),
            )
            pk = [r["column_name"] for r in cur.fetchall()]
            print(f"\nPrimary key: {pk or 'NONE'}")

            # Indexes (pg_indexes)
            cur.execute(
                """
                SELECT indexname, indexdef
                FROM pg_indexes
                WHERE schemaname = %s AND tablename = %s
                ORDER BY indexname;
                """,
                (schema, table_name),
            )
            idxs = cur.fetchall()
            print(f"\nIndexes ({len(idxs)}):")
            for i in idxs:
                print(f"  - {i['indexname']}: {i['indexdef']}")

            # Size on disk (human)
            cur.execute(
                """
                SELECT
                  pg_size_pretty(pg_total_relation_size(quote_ident(%s) || '.' || quote_ident(%s))) AS total_size,
                  pg_size_pretty(pg_relation_size(quote_ident(%s) || '.' || quote_ident(%s))) AS table_size
                """,
                (schema, table_name, schema, table_name),
            )
            size_info = cur.fetchone()
            print(f"\nSize: total={size_info['total_size']} table={size_info['table_size']}")

            # Approx row estimate from pg_class
            cur.execute(
                """
                SELECT reltuples::BIGINT AS estimate_rows
                FROM pg_class c
                JOIN pg_namespace n ON n.oid = c.relnamespace
                WHERE n.nspname = %s AND c.relname = %s;
                """,
                (schema, table_name),
            )
            est = cur.fetchone()
            print(f"Estimated rows (pg_class.reltuples): {est['estimate_rows'] if est else 'N/A'}")

            # Optional exact count (use sql module to safely format identifiers)
            if do_count:
                print("\nComputing exact COUNT(*) (may be slow)...")
                q = sql.SQL("SELECT count(*) AS exact_count FROM {}.{}").format(
                    sql.Identifier(schema), sql.Identifier(table_name)
                )
                cur.execute(q)
                cnt = cur.fetchone()
                print(f"Exact rows: {cnt['exact_count']}")
    except Exception as e:
        print(f"DB error: {e}")

# %%
list_tables()
# Out:
# ✓ Query executed:
#     SELECT table_schema, table_name
#     FROM information_schema.tables
#     WHERE table_type='BASE TABLE'
#       AND table_schema NOT IN ('pg_catalog','information_schema')
#     ORDER BY table_schema, table_name;
#
# RealDictRow([('table_schema', 'public'), ('table_name', 'Action')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Admin')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Answer')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'AnswerTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Attachment')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'AttachmentReference')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'BiometricDevice')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Category')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryOpenTime')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryOpenTimeTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'City')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Content')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentMascot')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentMascotMedia')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Gallery')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'GalleryTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Home')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'HomeTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Itinerary')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ItineraryPlace')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Notification')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'NotificationHistory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'OTP')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PhotoStory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Plan')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PlanAction')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PlanTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Poi')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiClassification')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiClean')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiPoiType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Profile')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Question')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'QuestionTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Quiz')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Review')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ReviewActions')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ReviewPhoto')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Route')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ScrapingCategory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ScrapingJob')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Transportation')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'TravelType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'User')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserAction')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserDeletionRequest')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserDevice')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItinerary')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItineraryGenerationLog')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItineraryPoi')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserPlan')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserPreferences')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'embedding')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'migrations')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'spatial_ref_sys')])

# %%
show_table_info("PoiClean")
# Out:
# Columns for public.PoiClean:
#   - id: uuid nullable=NO max_len=None
#   - created_at: timestamp without time zone nullable=NO max_len=None
#   - updatedAt: timestamp without time zone nullable=NO max_len=None
#   - deletedAt: timestamp without time zone nullable=YES max_len=None
#   - name: text nullable=NO max_len=None
#   - lat: double precision nullable=NO max_len=None
#   - address: text nullable=YES max_len=None
#   - poi_type: text nullable=YES max_len=None
#   - total_reviews: integer nullable=YES max_len=None
#   - lon: double precision nullable=NO max_len=None
#   - geom: USER-DEFINED nullable=NO max_len=None
#   - stay_time: double precision nullable=YES max_len=None
#   - avg_stars: double precision nullable=YES max_len=None
#   - normalize_stars_reviews: double precision nullable=YES max_len=None
#   - open_hours: json nullable=YES max_len=None
#   - poi_type_clean: text nullable=YES max_len=None
#   - main_subcategory: text nullable=YES max_len=None
#   - specialization: text nullable=YES max_len=None
#   - travel_type: json nullable=YES max_len=None
#
# Primary key: ['id']
#
# Indexes (1):
#   - PK_7c4fe1b3d5d29eb0b2c01753f2f: CREATE UNIQUE INDEX "PK_7c4fe1b3d5d29eb0b2c01753f2f" ON public."PoiClean" USING btree (id)
#
# Size: total=2392 kB table=2248 kB
# Estimated rows (pg_class.reltuples): 1454

# %%
file_path = os.path.join(os.getcwd(), "../data_csv/data_clean_normalize.csv")
print(f"File path: {file_path}")
# Out:
# File path: c:\Users\nguye\Desktop\vinamo\Main_Branch\Kyanon-support-localtion\scripts\ingest_db\../data_csv/data_clean_normalize.csv

# %%
df = pd.read_csv(file_path)
print(f"DataFrame loaded with {len(df)} rows and {len(df.columns)} columns.")
# Out:
# DataFrame loaded with 1454 rows and 19 columns.

# %%
df.head(2)
# Out:
#                                      id                              name  \
# 0  0f9d2009-9436-46a4-b354-b0261898a39e  The Pub Coffee - Beer & Cocktail
# 1  02887955-963a-43ac-b0f7-355d7d7cfacf                           Julieta
#
#                                              address        lat         lon  \
# 0  18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thà...  10.829481  106.773785
# 1  C. Sta. Lucía, 9, Distrito Centro, 29008 Málag...  36.722011   -4.421780
#
#    poi_type  avg_stars  total_reviews                               crowd  \
# 0  Cafe,Bar        4.9            181                              Groups
# 1      Cafe        4.3           2053  College students, Groups, Tourists
#
#                                            offerings            atmosphere  \
# 0      Alcohol, Beer, Cocktails, Coffee, Hard liquor          Casual, Cozy
# 1  Alcohol, Beer, Coffee, Healthy options, Organi...  Casual, Cozy, Trendy
#
#                                           highlights  \
# 0  Great beer selection, Great coffee, Live music...
# 1   Great coffee, Great dessert, Great tea selection
#
#                                       dining_options       children  \
# 0                                      Table service            NaN
# 1  Breakfast, Brunch, Lunch, Dessert, Seating, Ta...  Good for kids
#
#                                        accessibility  \
# 0                                                NaN
# 1  Wheelchair accessible entrance, Wheelchair acc...
#
#                              popular_for  \
# 0                                    NaN
# 1  Breakfast, Good for working on laptop
#
#                                        opening_hours  stay_time  \
# 0  [{'day': 'Monday', 'hours': [{'start': '00:00'...         30
# 1  [{'day': 'Monday', 'hours': [{'start': '08:00'...         30
#
#    normalize_stars_reviews
# 0                    0.755
# 1                    0.661

# %% [markdown]
# # Ingest data vào table PoiClean

# %%
UPSERT_SQL = """
INSERT INTO public."PoiClean" (
    id,
    name,
    address,
    lat,
    lon,
    geom,
    poi_type,
    avg_stars,
    total_reviews,
    stay_time,
    normalize_stars_reviews,
    created_at,
    "updatedAt",
    "deletedAt"
)
VALUES (
    # %s, %s, %s, %s, %s,
    ST_SetSRID(ST_MakePoint(%s, %s), 4326),
    # %s, %s, %s, %s, %s,
    NOW(),
    NOW(),
    NULL
)
ON CONFLICT (id) DO UPDATE SET
    name = EXCLUDED.name,
    address = EXCLUDED.address,
    lat = EXCLUDED.lat,
    lon = EXCLUDED.lon,
    geom = EXCLUDED.geom,
    poi_type = EXCLUDED.poi_type,
    avg_stars = EXCLUDED.avg_stars,
    total_reviews = EXCLUDED.total_reviews,
    stay_time = EXCLUDED.stay_time,
    normalize_stars_reviews = EXCLUDED.normalize_stars_reviews,
    "updatedAt" = NOW();
"""

# %%
# Mở connection
conn = get_db_connection()
cur = conn.cursor()

# %%
def import_csv_to_poi_clean(csv_file_path: str, batch_size: int = 500):
    total_rows = 0
    skipped_rows = 0

    try:
        with open(csv_file_path, "r", encoding="utf-8-sig") as file:
            reader = csv.DictReader(file)

            batch_data = []
    
            for row in reader:
                try:
                    # Required fields
                    if not row.get("id") or not row.get("lat") or not row.get("lon"):
                        skipped_rows += 1
                        continue

                    lat = float(row["lat"])
                    lon = float(row["lon"])

                    # Validate coordinates
                    if not (-90 <= lat <= 90 and -180 <= lon <= 180):
                        skipped_rows += 1
                        continue

                    avg_stars = float(row["avg_stars"]) if row.get("avg_stars") else None
                    total_reviews = int(row["total_reviews"]) if row.get("total_reviews") else None
                    stay_time = float(row["stay_time"]) if row.get("stay_time") else None
                    normalize_score = (
                        float(row["normalize_stars_reviews"])
                        if row.get("normalize_stars_reviews")
                        else None
                    )

                    batch_data.append((
                        row["id"],
                        row.get("name"),
                        row.get("address"),
                        lat,
                        lon,
                        lon,   # x for ST_MakePoint
                        lat,   # y for ST_MakePoint
                        row.get("poi_type"),
                        avg_stars,
                        total_reviews,
                        stay_time,
                        normalize_score
                    ))

                    if len(batch_data) >= batch_size:
                        execute_batch(cur, UPSERT_SQL, batch_data)
                        conn.commit()
                        total_rows += len(batch_data)
                        batch_data.clear()
                        print(f"  ✓ Imported {total_rows} records...")

                except Exception as e:
                    skipped_rows += 1
                    print(f"⚠ Skip row: {e}")

            if batch_data:
                execute_batch(cur, UPSERT_SQL, batch_data)
                conn.commit()
                total_rows += len(batch_data)

        # cur.close()

        print("\n🎉 IMPORT HOÀN TẤT")
        print(f"  - Thành công: {total_rows}")
        print(f"  - Bỏ qua: {skipped_rows}")

    except Exception as e:
        conn.rollback()
        print(f"❌ IMPORT FAILED: {e}")
        raise
    finally:
        conn.close()

def verify_data(limit: int = 5):
    cur.execute(f"""
        SELECT
            id,
            name,
            lat,
            lon,
            poi_type,
            avg_stars,
            total_reviews,
            stay_time,
            normalize_stars_reviews,
            ST_AsText(geom)
        FROM public."PoiClean"
        LIMIT {limit};
    """)

    print(f"\n🧪 SAMPLE DATA ({limit} rows):")
    for r in cur.fetchall():
        print(
            f"- {r[1]} | ({r[2]}, {r[3]}) | "
            f"⭐ {r[5]} | reviews={r[6]} | stay={r[7]} | geom={r[9]}"
        )

    cur.close()
    conn.close()

# %%
print("🚀 START IMPORT PoiClean")
print(f"📁 CSV: {file_path}")
print(f"🗄️ DB: {DB_NAME}@{DB_HOST}\n")

import_csv_to_poi_clean(file_path, batch_size=500)
verify_data(limit=5)

# %% [markdown]
# # Ingest thêm open_hours

# %%
# Mở connection
conn = get_db_connection()
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM "PoiClean"')
rows = cur.fetchall()
for poi in rows[:5]:
    print(poi)
# Out:
# RealDictRow([('id', '96451ce8-09ec-4b42-89ea-82534456e189'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'Bar tocata'), ('lat', 36.721288), ('address', 'C. Duque de la Victoria, 6, Distrito Centro, 29015 Málaga, Spain'), ('poi_type', 'Disco club,Bar,Night club'), ('total_reviews', 1321), ('lon', -4.4198423), ('geom', '0101000020E6100000E1E8CF23EBAD11C0A67F492A535C4240'), ('stay_time', 30.0), ('avg_stars', 4.0), ('normalize_stars_reviews', 0.556), ('open_hours', [{'day': 'Tuesday', 'hours': [{'start': '22:00', 'end': '03:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '22:00', 'end': '03:00'}]}, {'day': 'Thursday', 'hours': [{'start': '22:00', 'end': '03:00'}]}, {'day': 'Friday', 'hours': [{'start': '20:00', 'end': '04:00'}]}, {'day': 'Saturday', 'hours': [{'start': '18:00', 'end': '04:00'}]}, {'day': 'Sunday', 'hours': [{'start': '22:00', 'end': '03:00'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Nightclub'), ('specialization', 'Nightlife / Party'), ('travel_type', None)])
# RealDictRow([('id', '9c558348-a968-4624-87b2-56ae4450c302'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'BiaCraft Xuan Thuy | D.2'), ('lat', 10.8036674), ('address', '90 Xuân Thủy, Thảo Điền, Thủ Đức, Thành phố Hồ Chí Minh 70000, Vietnam'), ('poi_type', 'Gastropub,American restaurant,Bar,Brewery,Restaurant,Western restaurant'), ('total_reviews', 1624), ('lon', 106.7346477), ('geom', '0101000020E61000003965C97704AF5A4003B91F4B7A9B2540'), ('stay_time', 30.0), ('avg_stars', 4.6), ('normalize_stars_reviews', 0.743), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Tuesday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Thursday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Friday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Saturday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Sunday', 'hours': [{'start': '11:00', 'end': '00:00'}]}]), ('poi_type_clean', 'Restaurant'), ('main_subcategory', 'Casual Restaurant'), ('specialization', None), ('travel_type', None)])
# RealDictRow([('id', '3cd1901c-9293-4fe2-8dad-75ab597c4e7d'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'K-CITY (Korean Cafe & Bar)'), ('lat', 10.8044015), ('address', '19 Trần Ngọc Diện, Thảo Điền, Thủ Đức, Thành phố Hồ Chí Minh 700000, Vietnam'), ('poi_type', 'Bar,Disco club,Korean grocery store'), ('total_reviews', 15), ('lon', 106.7395528), ('geom', '0101000020E6100000936A44D554AF5A40EAB46E83DA9B2540'), ('stay_time', 30.0), ('avg_stars', 4.7), ('normalize_stars_reviews', 0.609), ('open_hours', [{'day': 'Tuesday', 'hours': [{'start': '14:00', 'end': '22:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '14:00', 'end': '22:00'}]}, {'day': 'Thursday', 'hours': [{'start': '14:00', 'end': '22:00'}]}, {'day': 'Friday', 'hours': [{'start': '14:00', 'end': '22:00'}]}, {'day': 'Saturday', 'hours': [{'start': '14:00', 'end': '22:00'}]}, {'day': 'Sunday', 'hours': [{'start': '14:00', 'end': '22:00'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Nightclub'), ('specialization', 'Nightlife / Party'), ('travel_type', None)])
# RealDictRow([('id', 'ece55a9b-8b2f-4067-bda3-309ca22c45b1'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'Canalis Club'), ('lat', 10.7873557), ('address', '264 Nam Kỳ Khởi Nghĩa, Phường Võ Thị Sáu, Quận 3, Thành phố Hồ Chí Minh, Vietnam'), ('poi_type', 'Disco club'), ('total_reviews', 1637), ('lon', 106.6868219), ('geom', '0101000020E61000004DABD7E3F4AB5A406DA34B4920932540'), ('stay_time', 30.0), ('avg_stars', 4.4), ('normalize_stars_reviews', 0.683), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '20:30', 'end': '03:30'}]}, {'day': 'Tuesday', 'hours': [{'start': '20:30', 'end': '03:30'}]}, {'day': 'Wednesday', 'hours': [{'start': '20:30', 'end': '03:30'}]}, {'day': 'Thursday', 'hours': [{'start': '20:30', 'end': '03:30'}]}, {'day': 'Friday', 'hours': [{'start': '20:30', 'end': '03:30'}]}, {'day': 'Saturday', 'hours': [{'start': '20:30', 'end': '03:30'}]}, {'day': 'Sunday', 'hours': [{'start': '20:30', 'end': '03:30'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Nightclub'), ('specialization', 'Nightlife / Party'), ('travel_type', None)])
# RealDictRow([('id', '13dcd2c6-6b8c-40e2-8513-1cc829236dbb'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'Gét Gô Rooftop'), ('lat', 10.80039), ('address', '348/9 Đ. Ung Văn Khiêm, Thạnh Mỹ Tây, Bình Thạnh, Thành phố Hồ Chí Minh 700000, Vietnam'), ('poi_type', 'Pub'), ('total_reviews', 166), ('lon', 106.7231601), ('geom', '0101000020E61000006AD14C4148AE5A404417D4B7CC992540'), ('stay_time', 30.0), ('avg_stars', 4.7), ('normalize_stars_reviews', 0.692), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '17:00', 'end': '00:30'}]}, {'day': 'Tuesday', 'hours': [{'start': '17:00', 'end': '00:30'}]}, {'day': 'Wednesday', 'hours': [{'start': '17:00', 'end': '00:30'}]}, {'day': 'Thursday', 'hours': [{'start': '17:00', 'end': '00:30'}]}, {'day': 'Friday', 'hours': [{'start': '17:00', 'end': '00:30'}]}, {'day': 'Saturday', 'hours': [{'start': '17:00', 'end': '00:30'}]}, {'day': 'Sunday', 'hours': [{'start': '17:00', 'end': '00:30'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Pub & Sports Bar'), ('specialization', 'Sports & Social'), ('travel_type', None)])

# %%
# Read the CSV file with opening_hours data
df_hours = pd.read_csv(file_path, encoding="utf-8", usecols=['id', 'opening_hours'])

# Display first few rows to verify
print(f"Total rows in CSV: {len(df_hours)}")
print(df_hours.head())
# Out:
# Total rows in CSV: 1454
#                                      id  \
# 0  0f9d2009-9436-46a4-b354-b0261898a39e
# 1  02887955-963a-43ac-b0f7-355d7d7cfacf
# 2  622c7643-30e8-4402-9b6c-b8407ff063e2
# 3  4f06908d-e9fa-4f6a-b1ae-c7d8882e2edf
# 4  279dfce3-c227-4b58-b4ed-09197327a32a
#
#                                        opening_hours
# 0  [{'day': 'Monday', 'hours': [{'start': '00:00'...
# 1  [{'day': 'Monday', 'hours': [{'start': '08:00'...
# 2  [{'day': 'Tuesday', 'hours': [{'start': '11:00...
# 3  [{'day': 'Tuesday', 'hours': [{'start': '17:30...
# 4  [{'day': 'Monday', 'hours': [{'start': '10:00'...

# %%
# Update open_hours in database from CSV data
updated_count = 0
skipped_count = 0
error_count = 0

for idx, row in df_hours.iterrows():
    poi_id = row['id']
    opening_hours = row['opening_hours']
    
    # Skip if opening_hours is null or empty
    if pd.isna(opening_hours) or opening_hours == '':
        skipped_count += 1
        continue
    
    try:
        # convert Python-like string -> valid JSON
        opening_hours_json = json.dumps(ast.literal_eval(opening_hours))

        cur.execute(
            'UPDATE "PoiClean" SET open_hours = %s WHERE id = %s',
            (opening_hours_json, poi_id)
        )
        updated_count += 1
        
        # Print progress every 100 records
        if (updated_count + skipped_count) % 100 == 0:
            print(f"Processed: {updated_count + skipped_count} records (Updated: {updated_count}, Skipped: {skipped_count})")
    except Exception as e:
        error_count += 1
        print(f"Error updating POI {poi_id}: {e}")

# Commit the changes
conn.commit()
print(f"\n✓ Update complete!")
print(f"Total Updated: {updated_count}")
print(f"Total Skipped: {skipped_count}")
print(f"Total Errors: {error_count}")

# %%
# Verify the update by checking a few POIs
verify_query = 'SELECT id, name, open_hours FROM "PoiClean" WHERE open_hours IS NOT NULL LIMIT 5'
cur.execute(verify_query)
results = cur.fetchall()

print("Sample of updated records:")
for poi in results:
    print(f"\nPOI: {poi['name']} (ID: {poi['id']})")
    print(f"Opening Hours: {poi['open_hours'][:100]}...")  # Print first 100 chars

# %% [markdown]
# # Ingest thêm từ json

# %%
file_path = os.path.join(os.getcwd(), "../data/results.json")

# %%
# Đọc file JSON
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)
print(type(data))
print(f"Total POI in JSON: {len(data)}")
print(data[3].get("main_subcategory"))  # In ra 2 POI đầu tiên để kiểm tra

# %%
# Update fields in database
updated_count = 0
skipped_count = 0
error_count = 0

for poi in data:
    poi_id = poi.get('id')
    poi_type_clean = poi.get('poi_type_new')        # có thể None
    main_subcategory = poi.get('main_subcategory')  # có thể None
    specialization = poi.get('specialization')      # có thể None

    try:
        cur.execute(
            '''UPDATE "PoiClean"
               SET poi_type_clean = %s,
                   main_subcategory = %s,
                   specialization = %s
               WHERE id = %s''',
            (poi_type_clean, main_subcategory, specialization, poi_id)
        )

        updated_count += 1

        # Print progress every 100 records
        if (updated_count + skipped_count) % 100 == 0:
            print(f"Processed: {updated_count + skipped_count} records "
                  f"(Updated: {updated_count}, Skipped: {skipped_count})")

    except Exception as e:
        error_count += 1
        print(f"Error updating POI {poi_id}: {e}")

# Commit
conn.commit()

print("\n✓ Update complete!")
print(f"Total Updated: {updated_count}")
print(f"Total Skipped: {skipped_count}")
print(f"Total Errors: {error_count}")

# %% [markdown]
# # Update poi_type_clean from "Cafe & Bakery" to "Cafe"

# %%
# Update poi_type_clean from "Cafe & Bakery" to "Cafe"

try:
    cur.execute(
        '''
        UPDATE "PoiClean"
        SET poi_type_clean = %s
        WHERE poi_type_clean = %s
        ''',
        ("History museum", "Local history museum")
    )

    affected_rows = cur.rowcount
    conn.commit()

    print(f"✓ Updated {affected_rows} records")

except Exception as e:
    conn.rollback()
    print(f"✗ Error updating poi_type_clean: {e}")

# %% [markdown]
# # ingest thêm stay_time và travel_type

# %%
file_path = os.path.join(os.getcwd(), "../generate_description/test_stay_time/result.json")
print(f"File path: {file_path}")
# Out:
# File path: c:\Users\nguye\Desktop\vinamo\Main_Branch\Kyanon-support-localtion\scripts\ingest_db\../generate_description/test_stay_time/result.json

# %%
# Đọc file JSON
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)
print(type(data))
print(f"Total POI in JSON: {len(data)}")
ơprint(data[3].get("main_subcategory"))  # In ra 2 POI đầu tiên để kiểm tra
# Out:
# <class 'list'>
# Total POI in JSON: 1454
# None

# %%
for poi in data[:3]:
    poi_id = poi.get('id')
    stay_time = poi.get('stay_time')  # có thể None
    suitability = poi.get('suitability')  # có thể None
    print(f"POI ID: {poi_id}, Stay Time: {stay_time}, Suitability: {suitability}")
    print(type(stay_time), type(suitability))
# Out:
# POI ID: 0f9d2009-9436-46a4-b354-b0261898a39e, Stay Time: 120, Suitability: {'Solo': 25, 'Couple': 40, 'Friends': 80, 'Family with kids': 10, 'Business traveler / free time': 30}
# <class 'int'> <class 'dict'>
# POI ID: 02887955-963a-43ac-b0f7-355d7d7cfacf, Stay Time: 90, Suitability: {'Solo': 70, 'Couple': 60, 'Friends': 50, 'Family with kids': 60, 'Business traveler / free time': 80}
# <class 'int'> <class 'dict'>
# POI ID: 622c7643-30e8-4402-9b6c-b8407ff063e2, Stay Time: 75, Suitability: {'Solo': 60, 'Couple': 70, 'Friends': 75, 'Family with kids': 80, 'Business traveler / free time': 50}
# <class 'int'> <class 'dict'>

# %%
import json
from psycopg2.extras import Json

# %%
# Update fields in database
updated_count = 0
skipped_count = 0
error_count = 0

for poi in data:
    poi_id = poi.get('id')
    stay_time = poi.get('stay_time')  # có thể None
    travel_type = poi.get('suitability')  # có thể None

    try:
        cur.execute(
            '''UPDATE "PoiClean"
               SET stay_time = %s,
                   travel_type = %s
               WHERE id = %s''',
             (stay_time, Json(travel_type), poi_id)
        )

        updated_count += 1

        # Print progress every 100 records
        if (updated_count + skipped_count) % 100 == 0:
            print(f"Processed: {updated_count + skipped_count} records "
                  f"(Updated: {updated_count}, Skipped: {skipped_count})")

    except Exception as e:
        error_count += 1
        print(f"Error updating POI {poi_id}: {e}")

# Commit
conn.commit()

print("\n✓ Update complete!")
print(f"Total Updated: {updated_count}")
print(f"Total Skipped: {skipped_count}")
print(f"Total Errors: {error_count}")
# Out:
# Processed: 100 records (Updated: 100, Skipped: 0)
# Processed: 200 records (Updated: 200, Skipped: 0)
# Processed: 300 records (Updated: 300, Skipped: 0)
# Processed: 400 records (Updated: 400, Skipped: 0)
# Processed: 500 records (Updated: 500, Skipped: 0)
# Processed: 600 records (Updated: 600, Skipped: 0)
# Processed: 700 records (Updated: 700, Skipped: 0)
# Processed: 800 records (Updated: 800, Skipped: 0)
# Processed: 900 records (Updated: 900, Skipped: 0)
# Processed: 1000 records (Updated: 1000, Skipped: 0)
# Processed: 1100 records (Updated: 1100, Skipped: 0)
# Processed: 1200 records (Updated: 1200, Skipped: 0)
# Processed: 1300 records (Updated: 1300, Skipped: 0)
# Processed: 1400 records (Updated: 1400, Skipped: 0)
#
# ✓ Update complete!
# Total Updated: 1454
# Total Skipped: 0
# Total Errors: 0

# %%
cur.execute('SELECT * FROM "PoiClean"')
rows = cur.fetchall()
for poi in rows[:5]:
    print(poi)
# Out:
# RealDictRow([('id', '96451ce8-09ec-4b42-89ea-82534456e189'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'Bar tocata'), ('lat', 36.721288), ('address', 'C. Duque de la Victoria, 6, Distrito Centro, 29015 Málaga, Spain'), ('poi_type', 'Disco club,Bar,Night club'), ('total_reviews', 1321), ('lon', -4.4198423), ('geom', '0101000020E6100000E1E8CF23EBAD11C0A67F492A535C4240'), ('stay_time', 120.0), ('avg_stars', 4.0), ('normalize_stars_reviews', 0.556), ('open_hours', [{'day': 'Tuesday', 'hours': [{'start': '22:00', 'end': '03:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '22:00', 'end': '03:00'}]}, {'day': 'Thursday', 'hours': [{'start': '22:00', 'end': '03:00'}]}, {'day': 'Friday', 'hours': [{'start': '20:00', 'end': '04:00'}]}, {'day': 'Saturday', 'hours': [{'start': '18:00', 'end': '04:00'}]}, {'day': 'Sunday', 'hours': [{'start': '22:00', 'end': '03:00'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Nightclub'), ('specialization', 'Nightlife / Party'), ('travel_type', {'Solo': 30, 'Couple': 50, 'Friends': 90, 'Family with kids': 0, 'Business traveler / free time': 10})])
# RealDictRow([('id', '9c558348-a968-4624-87b2-56ae4450c302'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'BiaCraft Xuan Thuy | D.2'), ('lat', 10.8036674), ('address', '90 Xuân Thủy, Thảo Điền, Thủ Đức, Thành phố Hồ Chí Minh 70000, Vietnam'), ('poi_type', 'Gastropub,American restaurant,Bar,Brewery,Restaurant,Western restaurant'), ('total_reviews', 1624), ('lon', 106.7346477), ('geom', '0101000020E61000003965C97704AF5A4003B91F4B7A9B2540'), ('stay_time', 90.0), ('avg_stars', 4.6), ('normalize_stars_reviews', 0.743), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Tuesday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Thursday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Friday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Saturday', 'hours': [{'start': '11:00', 'end': '00:00'}]}, {'day': 'Sunday', 'hours': [{'start': '11:00', 'end': '00:00'}]}]), ('poi_type_clean', 'Restaurant'), ('main_subcategory', 'Casual Restaurant'), ('specialization', None), ('travel_type', {'Solo': 60, 'Couple': 65, 'Friends': 85, 'Family with kids': 60, 'Business traveler / free time': 40})])
# RealDictRow([('id', '867507a9-ea26-4ad0-be3c-7a04f8ac829d'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'Mercadillo Barriada de El Palo'), ('lat', 36.7193029), ('address', 'Pl. Virgen Milagrosa, Málaga-Este, 29017 Málaga, Spain'), ('poi_type', 'Flea market'), ('total_reviews', 8), ('lon', -4.3636566), ('geom', '0101000020E6100000F1E54F65627411C080B50F1E125C4240'), ('stay_time', 60.0), ('avg_stars', 4.8), ('normalize_stars_reviews', 0.618), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Tuesday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Wednesday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Thursday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Friday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Saturday', 'hours': [{'start': '00:00', 'end': '23:59'}]}, {'day': 'Sunday', 'hours': [{'start': '00:00', 'end': '23:59'}]}]), ('poi_type_clean', 'Flea market'), ('main_subcategory', None), ('specialization', None), ('travel_type', {'Solo': 40, 'Couple': 50, 'Friends': 60, 'Family with kids': 70, 'Business traveler / free time': 10})])
# RealDictRow([('id', '311c234e-6026-4109-86b9-53e12cc98b52'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'The 6ix Saigon - Cocktail Bar'), ('lat', 10.808269), ('address', '36 Đường số 46, Thảo Điền, Thủ Đức, Thành phố Hồ Chí Minh, Vietnam'), ('poi_type', 'Cocktail bar,Bar,Live music bar,Lounge'), ('total_reviews', 83), ('lon', 106.7302446), ('geom', '0101000020E610000029C5D853BCAE5A40C2BD326FD59D2540'), ('stay_time', 120.0), ('avg_stars', 4.8), ('normalize_stars_reviews', 0.698), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '17:00', 'end': '01:00'}]}, {'day': 'Tuesday', 'hours': [{'start': '17:00', 'end': '01:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '17:00', 'end': '01:00'}]}, {'day': 'Thursday', 'hours': [{'start': '17:00', 'end': '01:00'}]}, {'day': 'Friday', 'hours': [{'start': '17:00', 'end': '01:00'}]}, {'day': 'Saturday', 'hours': [{'start': '17:00', 'end': '01:00'}]}]), ('poi_type_clean', 'Bar'), ('main_subcategory', 'Live Music Venue'), ('specialization', 'Live Entertainment'), ('travel_type', {'Solo': 35, 'Couple': 55, 'Friends': 85, 'Family with kids': 5, 'Business traveler / free time': 30})])
# RealDictRow([('id', '594f8556-99da-4eee-ba90-4a4141d2ce5b'), ('created_at', datetime.datetime(2026, 1, 7, 9, 28, 3, 360928)), ('updatedAt', datetime.datetime(2026, 1, 7, 9, 51, 40, 111841)), ('deletedAt', None), ('name', 'Cambara'), ('lat', 36.7147553), ('address', 'CC Muelle Uno, P.º del Muelle Uno, Local 65, Distrito Centro, 29016 Málaga, Spain'), ('poi_type', 'Restaurant,Mediterranean restaurant,Spanish restaurant,Valencian restaurant'), ('total_reviews', 9663), ('lon', -4.4148098), ('geom', '0101000020E6100000BF3D74E6C3A811C04312071A7D5B4240'), ('stay_time', 60.0), ('avg_stars', 4.6), ('normalize_stars_reviews', 0.806), ('open_hours', [{'day': 'Monday', 'hours': [{'start': '12:00', 'end': '00:00'}]}, {'day': 'Tuesday', 'hours': [{'start': '12:00', 'end': '00:00'}]}, {'day': 'Wednesday', 'hours': [{'start': '12:00', 'end': '00:00'}]}, {'day': 'Thursday', 'hours': [{'start': '12:00', 'end': '00:00'}]}, {'day': 'Friday', 'hours': [{'start': '12:00', 'end': '01:00'}]}, {'day': 'Saturday', 'hours': [{'start': '12:00', 'end': '01:00'}]}, {'day': 'Sunday', 'hours': [{'start': '12:00', 'end': '00:00'}]}]), ('poi_type_clean', 'Restaurant'), ('main_subcategory', 'Casual Restaurant'), ('specialization', None), ('travel_type', {'Solo': 60, 'Couple': 70, 'Friends': 70, 'Family with kids': 70, 'Business traveler / free time': 40})])
