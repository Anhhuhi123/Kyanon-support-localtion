# %%
import os
import sys
import csv
import argparse
import psycopg2
import pandas as pd
from psycopg2 import sql
from dotenv import load_dotenv
from psycopg2.extras import RealDictCursor
# Load .env from project root
load_dotenv()
# Out:
# True

# %% [markdown]
# # Connect database

# %%
# Env keys (fallbacks)
DB_HOST = os.getenv("DB_HOST", "localhost")
DB_PORT = int(os.getenv("DB_PORT", "5432"))
DB_NAME = os.getenv("DB_NAME", "postgres")
DB_USER = os.getenv("DB_USER", "")
DB_PASSWORD = os.getenv("DB_PASSWORD", "")
CONNECT_TIMEOUT = int(os.getenv("DB_CONNECT_TIMEOUT", "10"))

# %%
def get_db_connection():
    """
    Trả về psycopg2 connection sử dụng biến môi trường từ .env.
    """
    conn_kwargs = {
        "host": DB_HOST,
        "port": DB_PORT,
        "dbname": DB_NAME,
        "user": DB_USER,
        "password": DB_PASSWORD,
        "connect_timeout": CONNECT_TIMEOUT,
    }
    return psycopg2.connect(cursor_factory=RealDictCursor, **conn_kwargs)

def test_connection(sql_query: str = "SELECT now() AS now"):
    """
    Thực thi 1 câu SQL test và in kết quả.
    """
    conn = None
    try:
        conn = get_db_connection()
        with conn.cursor() as cur:
            cur.execute(sql_query)
            rows = cur.fetchall()
            print(f"✓ Query executed: {sql_query}")
            for row in rows:
                print(row)
    except Exception as e:
        print(f"DB error: {e}")
    finally:
        if conn:
            conn.close()

def list_tables():
    """Liệt kê các bảng hiện có (bỏ schema hệ thống)."""
    sql_query = """
    SELECT table_schema, table_name
    FROM information_schema.tables
    WHERE table_type='BASE TABLE'
      AND table_schema NOT IN ('pg_catalog','information_schema')
    ORDER BY table_schema, table_name;
    """
    test_connection(sql_query)

# %%
list_tables()
# Out:
# ✓ Query executed:
#     SELECT table_schema, table_name
#     FROM information_schema.tables
#     WHERE table_type='BASE TABLE'
#       AND table_schema NOT IN ('pg_catalog','information_schema')
#     ORDER BY table_schema, table_name;
#
# RealDictRow([('table_schema', 'public'), ('table_name', 'Action')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Admin')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Answer')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'AnswerTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Attachment')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'AttachmentReference')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'BiometricDevice')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Category')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryOpenTime')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryOpenTimeTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'CategoryTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'City')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Content')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentMascot')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentMascotMedia')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ContentTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Gallery')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'GalleryTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Home')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'HomeTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Itinerary')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ItineraryPlace')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Notification')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'NotificationHistory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'OTP')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PhotoStory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Plan')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PlanAction')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PlanTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Poi')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiClassification')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiClean')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiPoiType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'PoiType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Profile')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Question')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'QuestionTranslate')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Quiz')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Review')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ReviewActions')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ReviewPhoto')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Route')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ScrapingCategory')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'ScrapingJob')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'Transportation')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'TravelType')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'User')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserAction')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserDeletionRequest')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserDevice')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItinerary')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItineraryGenerationLog')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserItineraryPoi')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserPlan')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'UserPreferences')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'embedding')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'migrations')])
# RealDictRow([('table_schema', 'public'), ('table_name', 'spatial_ref_sys')])

# %%
# Mở connection
conn = get_db_connection()
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM "Poi"')
rows = cur.fetchall()
for poi in rows[:10]:
    print(poi)
# Out:
# RealDictRow([('id', '0f9d2009-9436-46a4-b354-b0261898a39e'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 45, 85061)), ('updatedAt', datetime.datetime(2025, 12, 6, 3, 43, 45, 85061)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"The Pub Coffee - Beer & Cocktail","placeId":"ChIJ7R9GGLQndTERJRircGTWzn4","description":"","lat":10.8294811,"long":106.7737852,"type":["Cafe","Bar"],"address":"18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thành phố Hồ Chí Minh, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/0d6d8596-ded7-4e10-954b-096aa2783725.jpg","photoUrls":["pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/0d6d8596-ded7-4e10-954b-096aa2783725.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/5f9da691-9b82-4ff2-86ea-7316f6f34028.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/7b15a9c4-8981-4255-be10-bd193951b4e2.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/95c293dc-86be-4fa0-b399-fed54b1f784d.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/aef8efda-45ce-4309-9785-6524c10e4d30.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/cd70d59d-945e-4942-9517-66f2d91dba5a.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/ceb00f6e-9f37-418f-b4a6-92e49c0512a5.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/d4af77fa-1308-4179-b7e9-74a9f17506f3.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/d6249b6a-8c87-4fd3-a078-c9bbdd637880.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/e318f6ae-572c-4af4-af87-cde7fd6c5e19.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '9137476420856649765', 'fid': '0x317527b418461fed:0x7eced66470ab1825', 'url': 'https://www.google.com/maps/search/?api=1&query=The%20Pub%20Coffee%20-%20Beer%20%26%20Cocktail&query_place_id=ChIJ7R9GGLQndTERJRircGTWzn4', 'city': 'Ho Chi Minh City', 'menu': None, 'rank': 1, 'kgmid': '/g/11fpkvlhz2', 'phone': '+84 974 188 353', 'price': None, 'state': 'Quận 9, Ho Chi Minh City', 'title': 'The Pub Coffee - Beer & Cocktail', 'emails': [], 'images': None, 'phones': [], 'street': '18A17 Tăng Nhơn Phú', 'address': '18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thành phố Hồ Chí Minh, Vietnam', 'orderBy': [], 'placeId': 'ChIJ7R9GGLQndTERJRircGTWzn4', 'reviews': [{'name': 'Thảo Thanh', 'text': 'Quán rộng rãi thoáng mát, giá cả sinh viên', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT21WaFR6QTVTblptZDBWQmRISTVTSFptYm1STmFsRRAB', 'publishAt': 'a week ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT21WaFR6QTVTblptZDBWQmRISTVTSFptYm1STmFsRRAB!2m1!1s0x0:0x7eced66470ab1825!3m1!1s2@1:CAIQACodChtycF9oOmVhTzA5SnZmd0VBdHI5SHZmbmRNalE%7C0d7_fx6BhHa%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '101403667203806476656', 'reviewerUrl': 'https://www.google.com/maps/contrib/101403667203806476656?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': 'Spacious and airy restaurant, student prices', 'publishedAtDate': '2025-11-23T00:53:17.120Z', 'reviewImageUrls': [], 'originalLanguage': 'vi', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a-/ALV-UjVzeWGK5_Oz2BrxR6WCrbY9bc3mJIXiDYqsbcMI-T3QqaGihcU=s1920-c-rp-mo-br100', 'translatedLanguage': 'en', 'reviewDetailedRating': {'Food': 5, 'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'reviewerNumberOfReviews': 1}, {'name': 'Hieu Pham', 'text': 'Anh nhân viên Trọng Trí quá tuyệt vời', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xWRGJtRktXVXMyVWpObmNISlhZVkpaVDNNNGIxRRAB', 'publishAt': '3 weeks ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xWRGJtRktXVXMyVWpObmNISlhZVkpaVDNNNGIxRRAB!2m1!1s0x0:0x7eced66470ab1825!3m1!1s2@1:CAIQACodChtycF9oOlVDbmFKWUs2UjNncHJXYVJZT3M4b1E%7C0d3ZEkoVNLU%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '112143220850485916789', 'reviewerUrl': 'https://www.google.com/maps/contrib/1121 ...
# RealDictRow([('id', '02887955-963a-43ac-b0f7-355d7d7cfacf'), ('created_at', datetime.datetime(2025, 9, 22, 7, 57, 6, 327067)), ('updatedAt', datetime.datetime(2025, 12, 2, 11, 45, 30, 228000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.722011,"city":"Málaga","long":-4.42178,"name":"Julieta","type":["Cafe"],"story":"Welcome to Julieta in Málaga, a hidden gem where history and culture intertwine! This charming spot, nestled in the heart of the city, evokes the spirit of Málaga\'s golden age. Did you know that Málaga was once a thriving hub during the Moorish rule? Now, it’s a hotspot on TikTok, with visitors raving about its vibrant arts scene and stunning street art! Local influencers are flocking here to capture the perfect Instagram shot, showcasing Julieta\'s unique blend of modernity and tradition. Take a stroll, breathe in the history, and let the essence of Málaga enchant you!","address":"C. Sta. Lucía, 9, Distrito Centro, 29008 Málaga, Spain","placeId":"ChIJAQBsIb73cg0Ryr5fBqJsUw4","imageUrl":"pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/fe3c1886-83a1-4bb8-ac78-a87f7801f2a6.jpg","photoUrls":["pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/fe3c1886-83a1-4bb8-ac78-a87f7801f2a6.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/7d8811d6-fc84-4820-bcc5-7b3f9186526b.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/cd51846f-9a45-49a7-916a-e7cf88841eb2.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/0e4b6ad3-8635-47b0-b669-9e7e02e05307.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/efc5854e-f656-4f3a-b5a4-76d61172773e.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/dfa48b83-9da7-4ce3-bd71-035672102283.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/9f529609-22eb-429c-899c-219b82c68962.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/1acca365-0cfe-4636-98de-bba102cd93b2.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/175f30a2-4863-4bf7-960b-f10e70931a1e.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/3acaaa45-f090-47ad-a713-33a520d4f94b.jpg"],"description":"Nestled in the heart of Málaga, Julieta is a charming café located at C. Sta. Lucía, 9, in the vibrant Distrito Centro. This delightful spot offers a warm, inviting atmosphere, perfect for sipping coffee while soaking in the local culture. With its rustic decor and friendly staff, Julieta serves a delectable array of pastries and traditional Spanish snacks, making it an ideal stop for breakfast or an afternoon treat. The café’s rich history and connection to the community add to its allure, inviting visitors to relax and enjoy the lively ambiance. Come experience the heart of Málaga at Julieta!"}'), ('raw_data', {'google': {'cid': '1032288182745415370', 'fid': '0xd72f7be216c0001:0xe536ca2065fbeca', 'url': 'https://www.google.com/maps/search/?api=1&query=Julieta&query_place_id=ChIJAQBsIb73cg0Ryr5fBqJsUw4', 'city': 'Málaga', 'menu': None, 'rank': 16, 'kgmid': '/g/11hcj3lxdk', 'phone': '+34 681 39 79 16', 'price': '€1–10', 'state': 'Málaga', 'title': 'Julieta', 'images': None, 'street': 'C. Sta. Lucía, 9', 'address': 'C. Sta. Lucía, 9, Distrito Centro, 29008 Málaga, Spain', 'orderBy': [{'name': 'Glovo', 'orderUrl': 'https://glovoapp.com/es/es/malaga/la-bella-julieta-malaga?utm_source=google&utm_medium=organic&utm_campaign=google_reserve_place_order_action'}, {'name': 'UberEats', 'orderUrl': 'https://www.ubereats.com/es/store/la-bella-julieta-santa-lucia/SOQMedOTXn2tskLdNumrhQ?utm_campaign=CM2508147-search-free-nonbrand-google-pas_e_all_acq_Global&utm_medium=search-free-nonbrand&utm_source=google-pas'}], 'placeId': 'ChIJAQBsIb73cg0Ryr5fBqJsUw4', 'reviews': [{'name': 'Arturas Karasiovas (Arturas Karasiovas)', 'text': 'We had a very delicious breakfast. However, the only downside was that, since we were sitting outside, the staff didn’t inform us that we needed to place our order inside, so we ended up waiting for a while. That said, the staff at the payment counter were very friendly, especially the guy who served us. The food was deli ...
# RealDictRow([('id', '622c7643-30e8-4402-9b6c-b8407ff063e2'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 44, 731328)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 44, 36, 507000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"BAIETA Restaurant Saigon Thao Dien","placeId":"ChIJRf35mx8ndTERFDWKEtT8BHQ","description":"","lat":10.802978,"long":106.727268,"type":["Restaurant","Bar","Cocktail bar","Coffee shop","Family restaurant","Mediterranean restaurant"],"address":"Nguyễn Văn Hưởng, Thảo Điền, 16/8, Thành phố Hồ Chí Minh 700000, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/13d7f738-b6fb-41e5-ba7e-36748f8f1632.jpg","photoUrls":["pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/13d7f738-b6fb-41e5-ba7e-36748f8f1632.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/4cbbf8bb-5ecb-480e-ba25-f3bed3e3343f.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/916e03c1-e47b-4d2d-baeb-30c0b0aa5188.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/96b080ad-11c3-4e41-b589-f6d5aa9b38c9.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/c4d9cccd-fce7-4290-ad78-6da3f4caec8d.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/d05f6a6c-fd66-4e07-8aff-716bd1b1bc3d.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/d73b0e7d-c086-4bc8-a60a-a5ab5bee8d1e.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/dfb88804-33ae-48de-980f-c91a3e2600d5.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/edb76456-3406-4c82-ba0c-8561466aeefd.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/f3f79b4f-5d8c-493b-bcb6-746a2b8a8de4.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '8360084796080796948', 'fid': '0x3175271f9bf9fd45:0x7404fcd4128a3514', 'url': 'https://www.google.com/maps/search/?api=1&query=BAIETA%20Restaurant%20Saigon%20Thao%20Dien&query_place_id=ChIJRf35mx8ndTERFDWKEtT8BHQ', 'city': 'Ho Chi Minh City', 'menu': 'https://baieta-restaurant.com/list/menu', 'rank': 44, 'depth': 0, 'kgmid': '/g/11svytm6sq', 'phone': '+84 902 700 863', 'price': None, 'state': '16/8, Ho Chi Minh City', 'title': 'BAIETA Restaurant Saigon Thao Dien', 'domain': 'baieta-restaurant.com', 'emails': [], 'images': None, 'phones': [], 'street': 'Nguyễn Văn Hưởng', 'address': 'Nguyễn Văn Hưởng, Thảo Điền, 16/8, Thành phố Hồ Chí Minh 700000, Vietnam', 'orderBy': [{'name': 'baieta-restaurant.com', 'orderUrl': 'https://baieta-restaurant.com/'}], 'placeId': 'ChIJRf35mx8ndTERFDWKEtT8BHQ', 'reddits': [], 'reviews': [{'name': 'CY K', 'text': '분위기 미쳤음!!\n모든 직원 영어 잘하고, 매우 친절함\n\n5시 해질녁부터 가서 있으니넘나 아름다움👍\n\n음식, 드링크 모두 가격대 있는편이고 음식이 손톱만큼 나오지만 이 모든걸 뷰가 커버해준다고 할수 있겠다!\n금요일 저녁부터는 예약 필수', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2paVGEwNXZURU4wUVVSa1ZHSkJVWEV4TkdvMmNFRRAB', 'publishAt': 'Edited an hour ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2paVGEwNXZURU4wUVVSa1ZHSkJVWEV4TkdvMmNFRRAB!2m1!1s0x0:0x7404fcd4128a3514!3m1!1s2@1:CAIQACodChtycF9oOjZTa05vTEN0QURkVGJBUXExNGo2cEE%7C0dBrp3imk1s%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '113496947416193187862', 'reviewerUrl': 'https://www.google.com/maps/contrib/113496947416193187862?hl=en', 'isLocalGuide': True, 'reviewOrigin': 'Google', 'reviewContext': {'Meal type': 'Dinner', 'Group size': '2 people, 3-4 people', 'Noise level': 'Moderate noise', 'Price per person': '₫700–800K'}, 'textTranslated': 'The atmosphere is crazy!!\nAll the staff speak English well and are very friendly.\n\nI went there around 5pm, and it was so beautiful👍\n\nThe food and drinks are on the pricey side, and the portions are small, but the view makes up for it!\nReservations are required starting Friday night.', 'publishedAtDate': '2025-12-06T00:48:04.785Z', 'reviewImageUrls': ['https://lh3.googleusercontent.com/geougc-cs/AMBA38sRzU2EURNaRMZwrs5c3Y2c4E28CMdXXTIP4qvmbj6YrXBpPyTlkjWktzqSl1U-CthNZQ6C30UQqmRU_quAE0jO0iXJjOkh-M2dSrVOAAWa0BDb1WCUpDMd6zHQa8yZvE2RowaHn5tSPHw', 'https://lh3.googleusercontent.com/ ...
# RealDictRow([('id', '4f06908d-e9fa-4f6a-b1ae-c7d8882e2edf'), ('created_at', datetime.datetime(2025, 10, 1, 3, 27, 4, 836357)), ('updatedAt', datetime.datetime(2026, 1, 7, 11, 22, 30, 479000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.7255541,"city":"Málaga","long":-4.4213208,"name":"Parroquia San Felipe Neri","type":["Catholic church","Tourist attraction"],"story":"Welcome to the Parroquia San Felipe Neri, a hidden gem in Málaga! This charming Baroque church, built in the 18th century, boasts stunning frescoes and a serene atmosphere. Fun fact: it was named after the beloved saint known for his playful spirit and love for children! Visitors on Instagram often rave about its tranquil ambiance, with many snapping photos of its ornate altar and peaceful courtyard. If you’re lucky, you might catch a glimpse of a local wedding, which has become a trending moment on TikTok. So, take a seat, listen to the whispers of history, and soak in the beauty of San Felipe Neri!","address":"C. Guerrero, 6, Distrito Centro, 29012 Málaga, Spain","placeId":"ChIJEfbQ6L73cg0RiM3qIjLLsmk","imageUrl":"pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/269b781f-6532-45b3-89a3-9fd44ef0c0c9.jpg","photoUrls":["pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/269b781f-6532-45b3-89a3-9fd44ef0c0c9.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/8818118a-cc76-4468-ba56-49ae2e60c329.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/168acc07-124a-4e3d-b7f8-bd198a6e3471.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/ef94bf03-4ec6-4038-8187-ddf87aafe177.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/d0f6a664-cbe6-4d49-ba13-36dfc303780b.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/66552a48-034a-46cd-8514-b2ca4ad258c3.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/1717ced5-a733-4af5-b6dd-415e9dfb327d.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/a30f13b1-58c1-4a92-8945-ac3edbf0bbea.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/93fbad53-ff50-43b4-9e23-7b87be080974.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/bc49fb6d-3af0-4578-be26-01b3befdde39.jpg"],"description":"Nestled in the heart of Málaga, the Parroquia San Felipe Neri is a stunning example of Baroque architecture that invites visitors to explore its rich history. Located at C. Guerrero, 6, this charming Catholic church boasts intricate altarpieces and a serene atmosphere, making it a perfect spot for reflection. As you step inside, the soft glow of sunlight filtering through stained glass illuminates the beautifully adorned interior, creating a peaceful ambiance. This hidden gem not only serves as a place of worship but also as a cultural landmark, reflecting the city\'s artistic heritage. Don’t miss the chance to discover this tranquil oasis in bustling Málaga!"}'), ('raw_data', {'google': {'cid': '7616373336031546760', 'fid': '0xd72f7bee8d0f611:0x69b2cb3222eacd88', 'url': 'https://www.google.com/maps/search/?api=1&query=Parroquia%20San%20Felipe%20Neri&query_place_id=ChIJEfbQ6L73cg0RiM3qIjLLsmk', 'city': 'Málaga', 'menu': None, 'rank': 19, 'kgmid': '/g/122fpsn6', 'phone': '+34 952 21 16 07', 'price': None, 'state': 'Málaga', 'title': 'Parroquia San Felipe Neri', 'images': None, 'street': 'C. Guerrero, 6', 'address': 'C. Guerrero, 6, Distrito Centro, 29012 Málaga, Spain', 'orderBy': [], 'placeId': 'ChIJEfbQ6L73cg0RiM3qIjLLsmk', 'reviews': [{'name': 'David Phipps', 'text': 'Worth a quick stop to look', 'stars': 5, 'rating': None, 'reviewId': 'ChZDSUhNMG9nS0VJQ0FnSUNtMG9UX0xBEAE', 'publishAt': '3 years ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNtMG9UX0xBEAE!2m1!1s0x0:0x69b2cb3222eacd88!3m1!1s2@1:CIHM0ogKEICAgICm0oT_LA%7C%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '101097237930536668213', 'reviewerUrl': 'https://www.google.com/maps/contrib/101097237930536668213?hl=en', 'isLocalGuide': True, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': None, 'publishedAtDate': ' ...
# RealDictRow([('id', '279dfce3-c227-4b58-b4ed-09197327a32a'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 44, 907090)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 44, 38, 621000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"BÀ BAR","placeId":"ChIJT6Dc7JondTERrxL9Ag22cTU","description":"","lat":10.8031895,"long":106.7283812,"type":["Cocktail bar","Cafe"],"address":"15 Đ. Nguyễn Cừ, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh 70000, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/02f83727-54aa-4a25-a624-4698c82ab650.jpg","photoUrls":["pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/02f83727-54aa-4a25-a624-4698c82ab650.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/19a3d61f-e09d-4b7a-b941-2287ba0562ae.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/22a12f96-b20c-4771-a0a4-040c16017edf.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/3b539dcd-157d-436a-995d-9aab2dcca5d1.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/4bf8a7db-2eca-4407-b85f-8103995891be.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/4e5b1e63-1a4a-4f62-9a58-f7535b241bd1.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/6a844be9-6e18-456d-b34b-7f1f1b098eba.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/cf94e08b-5ab9-441e-b47e-3e53e4201bcb.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/d09a0c0e-caff-4d51-8b6b-5629a0778b1a.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/e1b7b462-3a97-422a-b83b-ebc37024d66b.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '3851059323379454639', 'fid': '0x3175279aecdca04f:0x3571b60d02fd12af', 'url': 'https://www.google.com/maps/search/?api=1&query=B%C3%80%20BAR&query_place_id=ChIJT6Dc7JondTERrxL9Ag22cTU', 'city': 'Ho Chi Minh City', 'menu': 'https://drive.google.com/drive/folders/1-kd8_ikl4HxiCTzdZb9f9F9UC-4VEaoh', 'rank': 1, 'kgmid': '/g/11x31hwhk1', 'phone': '+84 387 223 038', 'price': None, 'state': 'Quan 2, Ho Chi Minh City', 'title': 'BÀ BAR', 'emails': [], 'images': None, 'phones': [], 'street': '15 Đ. Nguyễn Cừ', 'address': '15 Đ. Nguyễn Cừ, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh 70000, Vietnam', 'orderBy': [], 'placeId': 'ChIJT6Dc7JondTERrxL9Ag22cTU', 'reviews': [{'name': 'Tam Nhu Nguyen', 'text': 'Quán vui, nước ok. Tối t4 vui', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xoRVMzRTFNbGs1ZDFCeFgwRjBZMFpxTmw5SlVIYxAB', 'publishAt': '2 days ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xoRVMzRTFNbGs1ZDFCeFgwRjBZMFpxTmw5SlVIYxAB!2m1!1s0x0:0x3571b60d02fd12af!3m1!1s2@1:CAIQACodChtycF9oOlhES3E1Mlk5d1BxX0F0Y0ZqNl9JUHc%7C0dB4dt6bz7I%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '110868685349360257722', 'reviewerUrl': 'https://www.google.com/maps/contrib/110868685349360257722?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': 'Fun shop, ok drinks. Fun Wednesday night', 'publishedAtDate': '2025-12-03T15:42:49.127Z', 'reviewImageUrls': [], 'originalLanguage': 'vi', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a-/ALV-UjUmKutt-TylIRo6mNBbUcHt74yHLcew9tjKJHx43eQ8a7bb2mFS_A=s1920-c-rp-mo-br100', 'translatedLanguage': 'en', 'reviewDetailedRating': {}, 'responseFromOwnerDate': '2025-12-04T09:43:34.000Z', 'responseFromOwnerText': 'Dạ cảm ơn chị nhiều ạ', 'reviewerNumberOfReviews': 4}, {'name': 'Xuan Nam', 'text': 'nhà nhỏ xíu, phía trước là ngoài trời, trong nhà có máy lạnh mà tối, sida', 'stars': 2, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2pSVmJVcEVjMGRTVjJOc1dGVlBSVlF4YWpoQ2NFRRAB', 'publishAt': '2 days ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2pSVmJVcEVjMGRTVjJOc1dGVlBSVlF4YWpoQ2NFRRAB!2m1!1s0x0:0x3571b60d02fd12af!3m1!1s2@1:CAIQACodChtycF9oOjRVbUpEc0dSV2NsWFVPRVQxajhCcEE%7C0dAuZNRpmGn%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '108483542791555855381', 'reviewerUrl': 'https://www.google.com/m ...
# RealDictRow([('id', '1d66bcc3-7f32-42b6-8880-236437496c89'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 44, 552810)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 50, 48, 291000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"Art Bar Viet Nam","placeId":"ChIJoxiuV8wndTER8oq-i7-6Mr4","description":"","lat":10.8039632,"long":106.7290573,"type":["Bar","Art gallery","Cocktail bar"],"address":"29 Nguyễn Bá Huân, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/07c10978-ff43-4647-951b-5dc9c60acc97.jpg","photoUrls":["pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/07c10978-ff43-4647-951b-5dc9c60acc97.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/0895ab15-9491-4412-95b4-6f587f255f2c.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/0a4b4ab8-4137-4592-bbe9-4781eba17f36.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/3b624eff-248a-4e46-8d91-2f62fd729e13.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/3e9c630f-e107-4002-8911-9e83b081fa05.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/4dcffb55-3268-41cb-9321-f4537523a068.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/4fbdd9e2-76fa-4606-ac77-ea8bf8034081.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/5bee81d2-d737-4cb7-8053-b5e99173c695.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/7758a4a3-8c88-4374-9bbf-66987bd2e5e1.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/8ce78204-834b-40c2-9ae2-0752bd1feaf0.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '13705221947887880946', 'fid': '0x317527cc57ae18a3:0xbe32babf8bbe8af2', 'url': 'https://www.google.com/maps/search/?api=1&query=Art%20Bar%20Viet%20Nam&query_place_id=ChIJoxiuV8wndTER8oq-i7-6Mr4', 'city': 'Ho Chi Minh City', 'menu': 'https://www.facebook.com/photo.php?fbid=122126854790090513&set=pb.61552715402214.-2207520000&type=3', 'rank': 29, 'depth': 0, 'kgmid': '/g/11mqdfnj3n', 'phone': '+84 908 796 000', 'price': '₫200–300K', 'state': 'Quận 2, Ho Chi Minh City', 'title': 'Art Bar Viet Nam', 'domain': 'nhandan.vn', 'emails': ['nhandandientu@nhandan.vn', 'nhandantiengtrung@nhandan.vn', 'nhandanonline@nhandan.vn', 'nhandanenligne@nhandan.vn'], 'images': None, 'phones': ['+842439382413'], 'street': '29 Nguyễn Bá Huân', 'address': '29 Nguyễn Bá Huân, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh, Vietnam', 'orderBy': [{'name': 'zalo.me', 'orderUrl': 'https://zalo.me/0908796000'}, {'name': 'facebook.com', 'orderUrl': 'https://www.facebook.com/ArtBarVietNam'}], 'placeId': 'ChIJoxiuV8wndTER8oq-i7-6Mr4', 'reddits': [], 'reviews': [{'name': 'Momo Paton', 'text': "Great place if you enjoy art and cocktails, and don't want to listen to basic English pop. Thank you for the awesome service and cocktails 👌👌👌", 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xWSE1IVkVOMmxyVWs5VGFYTnJTWFF4YzNZMGFVRRAB', 'publishAt': 'a day ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xWSE1IVkVOMmxyVWs5VGFYTnJTWFF4YzNZMGFVRRAB!2m1!1s0x0:0xbe32babf8bbe8af2!3m1!1s2@1:CAIQACodChtycF9oOlVHMHVEN2lrUk9TaXNrSXQxc3Y0aUE%7C0dBNuQ8p-ml%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '112888223831495737979', 'reviewerUrl': 'https://www.google.com/maps/contrib/112888223831495737979?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {'Wait time': 'No wait', 'Group size': '3-4 people', 'Seating type': 'Bar area', 'Price per person': '₫400–500K', 'Wheelchair accessibility': 'For Vietnam, it is very wheelchair accessible'}, 'textTranslated': None, 'publishedAtDate': '2025-12-04T13:37:31.164Z', 'reviewImageUrls': [], 'originalLanguage': 'en', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a-/ALV-UjUrFoDTKXQgdW7ziuMQd1PJ5E4bri4qv63lDD2Deln-geKDulfZOA=s1920-c-rp-mo-br100', 'translatedLanguage': None, 'reviewDetailedRating': {'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'review ...
# RealDictRow([('id', '144c2596-83cc-43b1-9436-98cf19b15f4e'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 45, 235161)), ('updatedAt', datetime.datetime(2025, 12, 6, 3, 43, 45, 235161)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"Ngỡ Cafe | Cà phê view đẹp Thủ Đức | Coffee ngon Hiệp Bình Phước","placeId":"ChIJF0ks3mUpdTERPOx40nmQtOA","description":"","lat":10.8487013,"long":106.7224209,"type":["Coffee shop"],"address":"08 Đường số 8, Hiệp Bình Phước, Thủ Đức, Thành phố Hồ Chí Minh, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/67275f7d-a8ad-4904-9531-f158b8d53a62.jpg","photoUrls":["pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/67275f7d-a8ad-4904-9531-f158b8d53a62.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/67eb7b28-1660-42e8-944b-aacacbe05866.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/6e2ccd6b-0840-431d-b2b5-2dac567646ac.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/930742ad-8db5-4cba-8b51-aafeb76f94cb.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/9fcae78a-3a98-4ccf-9360-51d3e66b6470.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/a11cdb78-5d53-4df3-896c-2ea585ffc948.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/bc3e176b-272c-4153-bb44-6835cc3dace4.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/c7a4b374-69af-4cd6-9c1b-90fff571b16a.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/c9e86951-c801-4eb7-9a4f-0f771d35b35e.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/df8e08cc-9426-44e2-9721-84ba54b68986.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '16191725413200358460', 'fid': '0x31752965de2c4917:0xe0b49079d278ec3c', 'url': 'https://www.google.com/maps/search/?api=1&query=Ng%E1%BB%A1%20Cafe%20%7C%20C%C3%A0%20ph%C3%AA%20view%20%C4%91%E1%BA%B9p%20Th%E1%BB%A7%20%C4%90%E1%BB%A9c%20%7C%20Coffee%20ngon%20Hi%E1%BB%87p%20B%C3%ACnh%20Ph%C6%B0%E1%BB%9Bc&query_place_id=ChIJF0ks3mUpdTERPOx40nmQtOA', 'city': 'Ho Chi Minh City', 'menu': None, 'rank': 1, 'kgmid': '/g/11td41c7ck', 'phone': '+84 902 452 922', 'price': '₫1–100,000', 'state': 'Thủ Đức City, Ho Chi Minh City', 'title': 'Ngỡ Cafe | Cà phê view đẹp Thủ Đức | Coffee ngon Hiệp Bình Phước', 'emails': [], 'images': None, 'phones': [], 'street': '08 Đường số 8', 'address': '08 Đường số 8, Hiệp Bình Phước, Thủ Đức, Thành phố Hồ Chí Minh, Vietnam', 'orderBy': [], 'placeId': 'ChIJF0ks3mUpdTERPOx40nmQtOA', 'reviews': [{'name': 'Hoa Tran', 'text': None, 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2tkalYwcG5OSGh6T1VGRmMzSnlObkppVDFGTmFsRRAB', 'publishAt': '21 hours ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2tkalYwcG5OSGh6T1VGRmMzSnlObkppVDFGTmFsRRAB!2m1!1s0x0:0xe0b49079d278ec3c!3m1!1s2@1:CAIQACodChtycF9oOkdjV0pnNHhzOUFFc3JyNnJiT1FNalE%7C0dBI0UgcKK6%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '115332592448629788395', 'reviewerUrl': 'https://www.google.com/maps/contrib/115332592448629788395?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': None, 'publishedAtDate': '2025-12-04T06:55:27.748Z', 'reviewImageUrls': [], 'originalLanguage': None, 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a/ACg8ocJHmPKYOkeG_zqX6nojXds3N1yvXkVmGUTakZm9pTS8qyl4JA=s1920-c-rp-mo-br100', 'translatedLanguage': None, 'reviewDetailedRating': {'Food': 5, 'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'reviewerNumberOfReviews': 0}, {'name': 'Phương Hoàng', 'text': None, 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2tzNVJYSlFkVEJ2VjFSR2RGUmxSMGxpZVRSaU5IYxAB', 'publishAt': '5 days ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2tzNVJYSlFkVEJ2VjFSR2RGUmxSMGxpZVRSaU5IYxAB!2m1!1s0x0:0xe0b49079d278ec3c!3m1!1s2@1:CAIQACodChtycF9oOks5RXJQdTBvV1RGdFRlR0lieTRiNHc%7C0d9cNLNr7rZ%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId' ...
# RealDictRow([('id', '50510328-def5-497c-9ff6-c87eceb1d31a'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 45, 581144)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 44, 40, 554000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"TEEMAY COFFEE ROASTERS","placeId":"ChIJZ6m1awAndTERtwMNyjOiZTY","description":"","lat":10.8168497,"long":106.7284654,"type":["Coffee shop"],"address":"187 Nguyễn Văn Hưởng, Phường An Khánh, Thủ Đức, Thành phố Hồ Chí Minh 700000, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/07b3820a-704f-4dea-80dd-2444c034d8b9.jpg","photoUrls":["pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/07b3820a-704f-4dea-80dd-2444c034d8b9.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/134168e4-f426-4adc-b20d-3ba38f0f5a61.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/134e5727-9019-455a-bb30-f789afe855df.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/2346bf2a-71f8-4462-9be5-cb8b82753820.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/92f822af-dff6-4549-98f5-24b32fae3e20.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/a850a9bb-d07c-4695-b40d-449e2e2535b8.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/aadc9309-ab93-4c71-8058-3bd566a87f6e.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/c9dd909b-c144-4643-a7f1-a61efdacd4cd.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/dd56c7db-1537-4885-950b-87691e39d666.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/f86be75a-42ea-4de7-b902-ad5e517b6d0a.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '3919717394012767159', 'fid': '0x317527006bb5a967:0x3665a233ca0d03b7', 'url': 'https://www.google.com/maps/search/?api=1&query=TEEMAY%20COFFEE%20ROASTERS&query_place_id=ChIJZ6m1awAndTERtwMNyjOiZTY', 'city': 'Ho Chi Minh City', 'menu': None, 'rank': 2, 'depth': 0, 'kgmid': '/g/11ybk7m8fy', 'phone': '+84 901 189 007', 'price': '₫1–100,000', 'state': 'Thủ Đức City, Ho Chi Minh City', 'title': 'TEEMAY COFFEE ROASTERS', 'domain': 'teemaycoffee.com', 'emails': ['teemaycoffee@gmail.com'], 'images': None, 'phones': [], 'street': '187 Nguyễn Văn Hưởng', 'address': '187 Nguyễn Văn Hưởng, Phường An Khánh, Thủ Đức, Thành phố Hồ Chí Minh 700000, Vietnam', 'orderBy': [], 'placeId': 'ChIJZ6m1awAndTERtwMNyjOiZTY', 'reddits': [], 'reviews': [{'name': 'Anh Nguyễn tuan', 'text': 'The serving size is fair, not too small, and reasonably priced for the quality', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xoV2VuVnRYMGxDVUZsbmRIWlVVMlV4YUhwRVdWRRAB', 'publishAt': '22 hours ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xoV2VuVnRYMGxDVUZsbmRIWlVVMlV4YUhwRVdWRRAB!2m1!1s0x0:0x3665a233ca0d03b7!3m1!1s2@1:CAIQACodChtycF9oOlhWenVtX0lCUFlndHZUU2UxaHpEWVE%7C0dB_pXNWVjW%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '103142154357294457567', 'reviewerUrl': 'https://www.google.com/maps/contrib/103142154357294457567?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': None, 'publishedAtDate': '2025-12-05T04:19:46.411Z', 'reviewImageUrls': [], 'originalLanguage': 'en', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a/ACg8ocIUJPyTHdmuPi9V_4xmTbVTlHMdvtxlQUMKSahYTs2oyjLG8w=s1920-c-rp-mo-br100', 'translatedLanguage': None, 'reviewDetailedRating': {'Food': 5, 'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'reviewerNumberOfReviews': 0}, {'name': 'Ngocanh Tran', 'text': 'They play good music — light, instrumental, and easy on the ears', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xkV05VczNNMmhyVVZRd05FWmlhMEZ3TlZwNWNGRRAB', 'publishAt': '22 hours ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xkV05VczNNMmhyVVZRd05FWmlhMEZ3TlZwNWNGRRAB!2m1!1s0x0:0x3665a233ca0d03b7!3m1!1s2@1:CAIQACodChtycF9oOldWNUs3M2hrUVQwNEZia0FwNVp5cFE%7C0dB_XBhGmXH%7C?hl=en', 'visitedIn': None ...
# RealDictRow([('id', '5f1958f0-3c70-44e6-9ff0-a758909c28f5'), ('created_at', datetime.datetime(2025, 9, 27, 12, 46, 56, 454474)), ('updatedAt', datetime.datetime(2025, 12, 2, 11, 50, 35, 435000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.6985057,"city":"Málaga","long":-4.4368704,"name":"La Mafia se sienta a la mesa","type":["Italian restaurant","Bar & grill","Cocktail bar","Family restaurant","Northern Italian restaurant","Pizza delivery","Pizza restaurant","Pizza Takeout","Restaurant","Southern Italian restaurant"],"story":"Welcome to La Mafia se sienta a la mesa, a vibrant restaurant in Málaga that fuses Italian flavors with Andalusian charm! Did you know this spot is not just about delicious pasta and pizza? Opened in 2012, it quickly became a favorite, with over 200k followers on Instagram! Visitors rave about the cozy ambiance and friendly staff—perfect for a romantic dinner or a night out with friends. TikTok users are buzzing about their mouthwatering tiramisu, claiming it’s the best in town! So, as you savor each bite, remember you’re part of a culinary trend that celebrates both Italian heritage and Málaga\'s lively spirit! Enjoy!","address":"C/ Pacífico, 7, Carretera de Cádiz, 29004 Málaga, Spain","placeId":"ChIJldrwcyb5cg0RsfxIQZg-p8Y","imageUrl":"pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/7fdcd3cc-f5b0-4b4c-b78e-372516fda2f7.jpg","photoUrls":["pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/7fdcd3cc-f5b0-4b4c-b78e-372516fda2f7.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/36e9369d-7672-4ff8-96f9-e3f21ade598e.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/cf85c862-50b7-4276-8718-a3e4991227aa.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/02e9cfa9-d63e-488f-9411-6d5fc2922211.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/58411b5a-b14e-4c0b-bf65-2b0527be9eef.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/b51c358a-c85d-4d0a-aa6b-79e5b6e33dad.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/c0ca15cb-356f-4163-ab9d-78f1da216b24.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/e967ca28-8dac-481a-a2f2-89bea410c87b.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/1cf8b2b6-752a-4d5c-a86e-88bd5eda0ee2.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/2870ea3a-383f-481c-9f64-d3abacbedbf2.jpg"],"description":"Discover the culinary gem, La Mafia se sienta a la mesa, nestled at C/ Pacífico, 7 in the vibrant Carretera de Cádiz, Málaga. This delightful restaurant captures the essence of Northern and Southern Italian cuisine, offering a menu brimming with mouthwatering pizzas, hearty pastas, and delectable grilled dishes. With its warm, inviting atmosphere, adorned with rustic decor, it’s the perfect spot for families and friends alike. Enjoy expertly crafted cocktails at the bar or indulge in a cozy dinner while soaking in the lively ambiance. Don’t miss the chance to experience this taste of Italy right in Málaga—come savor the flavors today!"}'), ('raw_data', {'google': {'cid': '14314478764271664305', 'fid': '0xd72f92673f0da95:0xc6a73e984148fcb1', 'url': 'https://www.google.com/maps/search/?api=1&query=La%20Mafia%20se%20sienta%20a%20la%20mesa&query_place_id=ChIJldrwcyb5cg0RsfxIQZg-p8Y', 'city': 'Málaga', 'menu': 'https://lamafia.es/carta/', 'rank': 97, 'kgmid': '/g/11p56jptz1', 'phone': '+34 623 29 01 80', 'price': '€20–30', 'state': 'Málaga', 'title': 'La Mafia se sienta a la mesa', 'images': None, 'street': 'C/ Pacífico, 7', 'address': 'C/ Pacífico, 7, Carretera de Cádiz, 29004 Málaga, Spain', 'orderBy': [{'name': 'Glovo', 'orderUrl': 'https://glovoapp.com/es/es/malaga/la-mafia-se-sienta-a-la-mesa-2?utm_source=google&utm_medium=organic&utm_campaign=google_reserve_place_order_action'}, {'name': 'covermanager.com', 'orderUrl': 'https://www.covermanager.com/go/restaurante-lamafiasesientaalamesa/es'}, {'name': 'Just Eat', 'orderUrl': 'https://www.just-eat.es/restaurants-la-mafia-se-sienta-a-la-mesa-malaga-29004/menu?serviceType=delivery&utm_source=google&utm_medium=organic&utm_cam ...
# RealDictRow([('id', '96451ce8-09ec-4b42-89ea-82534456e189'), ('created_at', datetime.datetime(2025, 9, 27, 12, 50, 54, 33985)), ('updatedAt', datetime.datetime(2025, 12, 2, 11, 45, 40, 110000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.721288,"city":"Málaga","long":-4.4198423,"name":"Bar tocata","type":["Disco club","Bar","Night club"],"story":"Welcome to the enchanting POI Bar Tocata, nestled in the vibrant heart of Málaga! Here, where centuries of history meet modern flair, you can sip on local wines while surrounded by stunning mosaics that echo Málaga\'s rich Moorish past. Did you know that this city once served as a vital harbor for the Phoenicians and Romans? Today, TikTok users rave about the bar’s signature tapas, tagging it as a must-try spot in their foodie adventures. With its lively atmosphere and soulful music, Tocata is not just a bar; it\'s a celebration of Málaga’s spirit. Cheers to history and flavor in every bite!","address":"C. Duque de la Victoria, 6, Distrito Centro, 29015 Málaga, Spain","placeId":"ChIJ8YqyY5X3cg0RrXGy9r5Ffhg","imageUrl":"pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/d74ff8d8-318b-4fe3-8e5d-a731a688716f.jpg","photoUrls":["pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/d74ff8d8-318b-4fe3-8e5d-a731a688716f.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/b5031ca3-3f60-42c3-ace4-3c77205bb929.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/bec593de-b2c1-4192-a9c6-87ecea4ba8e1.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/4601eba8-1bba-4ca3-a8e0-844bdfb4bc81.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/b91cafba-58c8-4f3e-9311-d0b9c3008d1b.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/a7a5bf9c-8232-490c-84d7-5906e584a0a5.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/403a446d-29d2-4bce-913c-391f63c96f5e.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/e5139512-d87f-4b14-b9ef-8d077b67b61c.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/42edf80f-80fa-486c-a1c3-8e1643203649.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/38e03a54-4219-4e1e-af69-972f25c50fd3.jpg"],"description":"Nestled in the vibrant heart of Málaga, Bar Tocatá at C. Duque de la Victoria, 6, is a must-visit hotspot for night owls and music lovers alike. This lively disco club and bar pulses with energy, offering an eclectic mix of beats that will have you dancing until dawn. With its stylish decor and welcoming atmosphere, Bar Tocatá is the perfect place to unwind with friends or make new ones. Enjoy expertly crafted cocktails and immerse yourself in the local nightlife, where every night feels like a celebration. Come experience the magic of Málaga after dark!"}'), ('raw_data', {'google': {'cid': '1764924790460805549', 'fid': '0xd72f79563b28af1:0x187e45bef6b271ad', 'url': 'https://www.google.com/maps/search/?api=1&query=Bar%20tocata&query_place_id=ChIJ8YqyY5X3cg0RrXGy9r5Ffhg', 'city': 'Málaga', 'menu': None, 'rank': 16, 'kgmid': '/g/11b7l4k4p5', 'phone': '+34 722 86 55 95', 'price': '€1–10', 'state': 'Málaga', 'title': 'Bar tocata', 'images': None, 'street': 'C. Duque de la Victoria, 6', 'address': 'C. Duque de la Victoria, 6, Distrito Centro, 29015 Málaga, Spain', 'orderBy': [], 'placeId': 'ChIJ8YqyY5X3cg0RrXGy9r5Ffhg', 'reviews': [{'name': 'Víctor Peinado González', 'text': 'Perfect place to enjoy the night! It was amazing… people, music. We will go again 100%. Thanks for the service', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xCNlQyUkNUa3d5VkVod1dub3pTMGxsYUZaWmNWRRAB', 'publishAt': '2 months ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xCNlQyUkNUa3d5VkVod1dub3pTMGxsYUZaWmNWRRAB!2m1!1s0x0:0x187e45bef6b271ad!3m1!1s2@1:CAIQACodChtycF9oOlB6T2RCTkwyVEhwWnozS0llaFZZcVE%7C%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '111342596225375141547', 'reviewerUrl': 'https://www.google.com/maps/contrib/111342596225375141547?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'review ...

# %%
cur.execute('SELECT * FROM "Poi"')
rows = cur.fetchall()
for poi in rows[:10]:
    print(poi)
# Out:
# RealDictRow([('id', '0f9d2009-9436-46a4-b354-b0261898a39e'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 45, 85061)), ('updatedAt', datetime.datetime(2025, 12, 6, 3, 43, 45, 85061)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"The Pub Coffee - Beer & Cocktail","placeId":"ChIJ7R9GGLQndTERJRircGTWzn4","description":"","lat":10.8294811,"long":106.7737852,"type":["Cafe","Bar"],"address":"18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thành phố Hồ Chí Minh, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/0d6d8596-ded7-4e10-954b-096aa2783725.jpg","photoUrls":["pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/0d6d8596-ded7-4e10-954b-096aa2783725.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/5f9da691-9b82-4ff2-86ea-7316f6f34028.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/7b15a9c4-8981-4255-be10-bd193951b4e2.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/95c293dc-86be-4fa0-b399-fed54b1f784d.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/aef8efda-45ce-4309-9785-6524c10e4d30.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/cd70d59d-945e-4942-9517-66f2d91dba5a.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/ceb00f6e-9f37-418f-b4a6-92e49c0512a5.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/d4af77fa-1308-4179-b7e9-74a9f17506f3.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/d6249b6a-8c87-4fd3-a078-c9bbdd637880.jpg","pois/images/ChIJ7R9GGLQndTERJRircGTWzn4/e318f6ae-572c-4af4-af87-cde7fd6c5e19.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '9137476420856649765', 'fid': '0x317527b418461fed:0x7eced66470ab1825', 'url': 'https://www.google.com/maps/search/?api=1&query=The%20Pub%20Coffee%20-%20Beer%20%26%20Cocktail&query_place_id=ChIJ7R9GGLQndTERJRircGTWzn4', 'city': 'Ho Chi Minh City', 'menu': None, 'rank': 1, 'kgmid': '/g/11fpkvlhz2', 'phone': '+84 974 188 353', 'price': None, 'state': 'Quận 9, Ho Chi Minh City', 'title': 'The Pub Coffee - Beer & Cocktail', 'emails': [], 'images': None, 'phones': [], 'street': '18A17 Tăng Nhơn Phú', 'address': '18A17 Tăng Nhơn Phú, Phước Long B, Quận 9, Thành phố Hồ Chí Minh, Vietnam', 'orderBy': [], 'placeId': 'ChIJ7R9GGLQndTERJRircGTWzn4', 'reviews': [{'name': 'Thảo Thanh', 'text': 'Quán rộng rãi thoáng mát, giá cả sinh viên', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT21WaFR6QTVTblptZDBWQmRISTVTSFptYm1STmFsRRAB', 'publishAt': 'a week ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT21WaFR6QTVTblptZDBWQmRISTVTSFptYm1STmFsRRAB!2m1!1s0x0:0x7eced66470ab1825!3m1!1s2@1:CAIQACodChtycF9oOmVhTzA5SnZmd0VBdHI5SHZmbmRNalE%7C0d7_fx6BhHa%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '101403667203806476656', 'reviewerUrl': 'https://www.google.com/maps/contrib/101403667203806476656?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': 'Spacious and airy restaurant, student prices', 'publishedAtDate': '2025-11-23T00:53:17.120Z', 'reviewImageUrls': [], 'originalLanguage': 'vi', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a-/ALV-UjVzeWGK5_Oz2BrxR6WCrbY9bc3mJIXiDYqsbcMI-T3QqaGihcU=s1920-c-rp-mo-br100', 'translatedLanguage': 'en', 'reviewDetailedRating': {'Food': 5, 'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'reviewerNumberOfReviews': 1}, {'name': 'Hieu Pham', 'text': 'Anh nhân viên Trọng Trí quá tuyệt vời', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xWRGJtRktXVXMyVWpObmNISlhZVkpaVDNNNGIxRRAB', 'publishAt': '3 weeks ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xWRGJtRktXVXMyVWpObmNISlhZVkpaVDNNNGIxRRAB!2m1!1s0x0:0x7eced66470ab1825!3m1!1s2@1:CAIQACodChtycF9oOlVDbmFKWUs2UjNncHJXYVJZT3M4b1E%7C0d3ZEkoVNLU%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '112143220850485916789', 'reviewerUrl': 'https://www.google.com/maps/contrib/1121 ...
# RealDictRow([('id', '02887955-963a-43ac-b0f7-355d7d7cfacf'), ('created_at', datetime.datetime(2025, 9, 22, 7, 57, 6, 327067)), ('updatedAt', datetime.datetime(2025, 12, 2, 11, 45, 30, 228000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.722011,"city":"Málaga","long":-4.42178,"name":"Julieta","type":["Cafe"],"story":"Welcome to Julieta in Málaga, a hidden gem where history and culture intertwine! This charming spot, nestled in the heart of the city, evokes the spirit of Málaga\'s golden age. Did you know that Málaga was once a thriving hub during the Moorish rule? Now, it’s a hotspot on TikTok, with visitors raving about its vibrant arts scene and stunning street art! Local influencers are flocking here to capture the perfect Instagram shot, showcasing Julieta\'s unique blend of modernity and tradition. Take a stroll, breathe in the history, and let the essence of Málaga enchant you!","address":"C. Sta. Lucía, 9, Distrito Centro, 29008 Málaga, Spain","placeId":"ChIJAQBsIb73cg0Ryr5fBqJsUw4","imageUrl":"pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/fe3c1886-83a1-4bb8-ac78-a87f7801f2a6.jpg","photoUrls":["pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/fe3c1886-83a1-4bb8-ac78-a87f7801f2a6.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/7d8811d6-fc84-4820-bcc5-7b3f9186526b.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/cd51846f-9a45-49a7-916a-e7cf88841eb2.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/0e4b6ad3-8635-47b0-b669-9e7e02e05307.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/efc5854e-f656-4f3a-b5a4-76d61172773e.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/dfa48b83-9da7-4ce3-bd71-035672102283.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/9f529609-22eb-429c-899c-219b82c68962.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/1acca365-0cfe-4636-98de-bba102cd93b2.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/175f30a2-4863-4bf7-960b-f10e70931a1e.jpg","pois/images/ChIJAQBsIb73cg0Ryr5fBqJsUw4/3acaaa45-f090-47ad-a713-33a520d4f94b.jpg"],"description":"Nestled in the heart of Málaga, Julieta is a charming café located at C. Sta. Lucía, 9, in the vibrant Distrito Centro. This delightful spot offers a warm, inviting atmosphere, perfect for sipping coffee while soaking in the local culture. With its rustic decor and friendly staff, Julieta serves a delectable array of pastries and traditional Spanish snacks, making it an ideal stop for breakfast or an afternoon treat. The café’s rich history and connection to the community add to its allure, inviting visitors to relax and enjoy the lively ambiance. Come experience the heart of Málaga at Julieta!"}'), ('raw_data', {'google': {'cid': '1032288182745415370', 'fid': '0xd72f7be216c0001:0xe536ca2065fbeca', 'url': 'https://www.google.com/maps/search/?api=1&query=Julieta&query_place_id=ChIJAQBsIb73cg0Ryr5fBqJsUw4', 'city': 'Málaga', 'menu': None, 'rank': 16, 'kgmid': '/g/11hcj3lxdk', 'phone': '+34 681 39 79 16', 'price': '€1–10', 'state': 'Málaga', 'title': 'Julieta', 'images': None, 'street': 'C. Sta. Lucía, 9', 'address': 'C. Sta. Lucía, 9, Distrito Centro, 29008 Málaga, Spain', 'orderBy': [{'name': 'Glovo', 'orderUrl': 'https://glovoapp.com/es/es/malaga/la-bella-julieta-malaga?utm_source=google&utm_medium=organic&utm_campaign=google_reserve_place_order_action'}, {'name': 'UberEats', 'orderUrl': 'https://www.ubereats.com/es/store/la-bella-julieta-santa-lucia/SOQMedOTXn2tskLdNumrhQ?utm_campaign=CM2508147-search-free-nonbrand-google-pas_e_all_acq_Global&utm_medium=search-free-nonbrand&utm_source=google-pas'}], 'placeId': 'ChIJAQBsIb73cg0Ryr5fBqJsUw4', 'reviews': [{'name': 'Arturas Karasiovas (Arturas Karasiovas)', 'text': 'We had a very delicious breakfast. However, the only downside was that, since we were sitting outside, the staff didn’t inform us that we needed to place our order inside, so we ended up waiting for a while. That said, the staff at the payment counter were very friendly, especially the guy who served us. The food was deli ...
# RealDictRow([('id', '622c7643-30e8-4402-9b6c-b8407ff063e2'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 44, 731328)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 44, 36, 507000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"BAIETA Restaurant Saigon Thao Dien","placeId":"ChIJRf35mx8ndTERFDWKEtT8BHQ","description":"","lat":10.802978,"long":106.727268,"type":["Restaurant","Bar","Cocktail bar","Coffee shop","Family restaurant","Mediterranean restaurant"],"address":"Nguyễn Văn Hưởng, Thảo Điền, 16/8, Thành phố Hồ Chí Minh 700000, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/13d7f738-b6fb-41e5-ba7e-36748f8f1632.jpg","photoUrls":["pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/13d7f738-b6fb-41e5-ba7e-36748f8f1632.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/4cbbf8bb-5ecb-480e-ba25-f3bed3e3343f.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/916e03c1-e47b-4d2d-baeb-30c0b0aa5188.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/96b080ad-11c3-4e41-b589-f6d5aa9b38c9.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/c4d9cccd-fce7-4290-ad78-6da3f4caec8d.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/d05f6a6c-fd66-4e07-8aff-716bd1b1bc3d.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/d73b0e7d-c086-4bc8-a60a-a5ab5bee8d1e.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/dfb88804-33ae-48de-980f-c91a3e2600d5.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/edb76456-3406-4c82-ba0c-8561466aeefd.jpg","pois/images/ChIJRf35mx8ndTERFDWKEtT8BHQ/f3f79b4f-5d8c-493b-bcb6-746a2b8a8de4.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '8360084796080796948', 'fid': '0x3175271f9bf9fd45:0x7404fcd4128a3514', 'url': 'https://www.google.com/maps/search/?api=1&query=BAIETA%20Restaurant%20Saigon%20Thao%20Dien&query_place_id=ChIJRf35mx8ndTERFDWKEtT8BHQ', 'city': 'Ho Chi Minh City', 'menu': 'https://baieta-restaurant.com/list/menu', 'rank': 44, 'depth': 0, 'kgmid': '/g/11svytm6sq', 'phone': '+84 902 700 863', 'price': None, 'state': '16/8, Ho Chi Minh City', 'title': 'BAIETA Restaurant Saigon Thao Dien', 'domain': 'baieta-restaurant.com', 'emails': [], 'images': None, 'phones': [], 'street': 'Nguyễn Văn Hưởng', 'address': 'Nguyễn Văn Hưởng, Thảo Điền, 16/8, Thành phố Hồ Chí Minh 700000, Vietnam', 'orderBy': [{'name': 'baieta-restaurant.com', 'orderUrl': 'https://baieta-restaurant.com/'}], 'placeId': 'ChIJRf35mx8ndTERFDWKEtT8BHQ', 'reddits': [], 'reviews': [{'name': 'CY K', 'text': '분위기 미쳤음!!\n모든 직원 영어 잘하고, 매우 친절함\n\n5시 해질녁부터 가서 있으니넘나 아름다움👍\n\n음식, 드링크 모두 가격대 있는편이고 음식이 손톱만큼 나오지만 이 모든걸 뷰가 커버해준다고 할수 있겠다!\n금요일 저녁부터는 예약 필수', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2paVGEwNXZURU4wUVVSa1ZHSkJVWEV4TkdvMmNFRRAB', 'publishAt': 'Edited an hour ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2paVGEwNXZURU4wUVVSa1ZHSkJVWEV4TkdvMmNFRRAB!2m1!1s0x0:0x7404fcd4128a3514!3m1!1s2@1:CAIQACodChtycF9oOjZTa05vTEN0QURkVGJBUXExNGo2cEE%7C0dBrp3imk1s%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '113496947416193187862', 'reviewerUrl': 'https://www.google.com/maps/contrib/113496947416193187862?hl=en', 'isLocalGuide': True, 'reviewOrigin': 'Google', 'reviewContext': {'Meal type': 'Dinner', 'Group size': '2 people, 3-4 people', 'Noise level': 'Moderate noise', 'Price per person': '₫700–800K'}, 'textTranslated': 'The atmosphere is crazy!!\nAll the staff speak English well and are very friendly.\n\nI went there around 5pm, and it was so beautiful👍\n\nThe food and drinks are on the pricey side, and the portions are small, but the view makes up for it!\nReservations are required starting Friday night.', 'publishedAtDate': '2025-12-06T00:48:04.785Z', 'reviewImageUrls': ['https://lh3.googleusercontent.com/geougc-cs/AMBA38sRzU2EURNaRMZwrs5c3Y2c4E28CMdXXTIP4qvmbj6YrXBpPyTlkjWktzqSl1U-CthNZQ6C30UQqmRU_quAE0jO0iXJjOkh-M2dSrVOAAWa0BDb1WCUpDMd6zHQa8yZvE2RowaHn5tSPHw', 'https://lh3.googleusercontent.com/ ...
# RealDictRow([('id', '4f06908d-e9fa-4f6a-b1ae-c7d8882e2edf'), ('created_at', datetime.datetime(2025, 10, 1, 3, 27, 4, 836357)), ('updatedAt', datetime.datetime(2026, 1, 7, 11, 22, 30, 479000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.7255541,"city":"Málaga","long":-4.4213208,"name":"Parroquia San Felipe Neri","type":["Catholic church","Tourist attraction"],"story":"Welcome to the Parroquia San Felipe Neri, a hidden gem in Málaga! This charming Baroque church, built in the 18th century, boasts stunning frescoes and a serene atmosphere. Fun fact: it was named after the beloved saint known for his playful spirit and love for children! Visitors on Instagram often rave about its tranquil ambiance, with many snapping photos of its ornate altar and peaceful courtyard. If you’re lucky, you might catch a glimpse of a local wedding, which has become a trending moment on TikTok. So, take a seat, listen to the whispers of history, and soak in the beauty of San Felipe Neri!","address":"C. Guerrero, 6, Distrito Centro, 29012 Málaga, Spain","placeId":"ChIJEfbQ6L73cg0RiM3qIjLLsmk","imageUrl":"pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/269b781f-6532-45b3-89a3-9fd44ef0c0c9.jpg","photoUrls":["pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/269b781f-6532-45b3-89a3-9fd44ef0c0c9.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/8818118a-cc76-4468-ba56-49ae2e60c329.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/168acc07-124a-4e3d-b7f8-bd198a6e3471.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/ef94bf03-4ec6-4038-8187-ddf87aafe177.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/d0f6a664-cbe6-4d49-ba13-36dfc303780b.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/66552a48-034a-46cd-8514-b2ca4ad258c3.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/1717ced5-a733-4af5-b6dd-415e9dfb327d.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/a30f13b1-58c1-4a92-8945-ac3edbf0bbea.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/93fbad53-ff50-43b4-9e23-7b87be080974.jpg","pois/images/ChIJEfbQ6L73cg0RiM3qIjLLsmk/bc49fb6d-3af0-4578-be26-01b3befdde39.jpg"],"description":"Nestled in the heart of Málaga, the Parroquia San Felipe Neri is a stunning example of Baroque architecture that invites visitors to explore its rich history. Located at C. Guerrero, 6, this charming Catholic church boasts intricate altarpieces and a serene atmosphere, making it a perfect spot for reflection. As you step inside, the soft glow of sunlight filtering through stained glass illuminates the beautifully adorned interior, creating a peaceful ambiance. This hidden gem not only serves as a place of worship but also as a cultural landmark, reflecting the city\'s artistic heritage. Don’t miss the chance to discover this tranquil oasis in bustling Málaga!"}'), ('raw_data', {'google': {'cid': '7616373336031546760', 'fid': '0xd72f7bee8d0f611:0x69b2cb3222eacd88', 'url': 'https://www.google.com/maps/search/?api=1&query=Parroquia%20San%20Felipe%20Neri&query_place_id=ChIJEfbQ6L73cg0RiM3qIjLLsmk', 'city': 'Málaga', 'menu': None, 'rank': 19, 'kgmid': '/g/122fpsn6', 'phone': '+34 952 21 16 07', 'price': None, 'state': 'Málaga', 'title': 'Parroquia San Felipe Neri', 'images': None, 'street': 'C. Guerrero, 6', 'address': 'C. Guerrero, 6, Distrito Centro, 29012 Málaga, Spain', 'orderBy': [], 'placeId': 'ChIJEfbQ6L73cg0RiM3qIjLLsmk', 'reviews': [{'name': 'David Phipps', 'text': 'Worth a quick stop to look', 'stars': 5, 'rating': None, 'reviewId': 'ChZDSUhNMG9nS0VJQ0FnSUNtMG9UX0xBEAE', 'publishAt': '3 years ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNtMG9UX0xBEAE!2m1!1s0x0:0x69b2cb3222eacd88!3m1!1s2@1:CIHM0ogKEICAgICm0oT_LA%7C%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '101097237930536668213', 'reviewerUrl': 'https://www.google.com/maps/contrib/101097237930536668213?hl=en', 'isLocalGuide': True, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': None, 'publishedAtDate': ' ...
# RealDictRow([('id', '279dfce3-c227-4b58-b4ed-09197327a32a'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 44, 907090)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 44, 38, 621000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"BÀ BAR","placeId":"ChIJT6Dc7JondTERrxL9Ag22cTU","description":"","lat":10.8031895,"long":106.7283812,"type":["Cocktail bar","Cafe"],"address":"15 Đ. Nguyễn Cừ, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh 70000, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/02f83727-54aa-4a25-a624-4698c82ab650.jpg","photoUrls":["pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/02f83727-54aa-4a25-a624-4698c82ab650.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/19a3d61f-e09d-4b7a-b941-2287ba0562ae.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/22a12f96-b20c-4771-a0a4-040c16017edf.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/3b539dcd-157d-436a-995d-9aab2dcca5d1.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/4bf8a7db-2eca-4407-b85f-8103995891be.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/4e5b1e63-1a4a-4f62-9a58-f7535b241bd1.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/6a844be9-6e18-456d-b34b-7f1f1b098eba.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/cf94e08b-5ab9-441e-b47e-3e53e4201bcb.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/d09a0c0e-caff-4d51-8b6b-5629a0778b1a.jpg","pois/images/ChIJT6Dc7JondTERrxL9Ag22cTU/e1b7b462-3a97-422a-b83b-ebc37024d66b.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '3851059323379454639', 'fid': '0x3175279aecdca04f:0x3571b60d02fd12af', 'url': 'https://www.google.com/maps/search/?api=1&query=B%C3%80%20BAR&query_place_id=ChIJT6Dc7JondTERrxL9Ag22cTU', 'city': 'Ho Chi Minh City', 'menu': 'https://drive.google.com/drive/folders/1-kd8_ikl4HxiCTzdZb9f9F9UC-4VEaoh', 'rank': 1, 'kgmid': '/g/11x31hwhk1', 'phone': '+84 387 223 038', 'price': None, 'state': 'Quan 2, Ho Chi Minh City', 'title': 'BÀ BAR', 'emails': [], 'images': None, 'phones': [], 'street': '15 Đ. Nguyễn Cừ', 'address': '15 Đ. Nguyễn Cừ, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh 70000, Vietnam', 'orderBy': [], 'placeId': 'ChIJT6Dc7JondTERrxL9Ag22cTU', 'reviews': [{'name': 'Tam Nhu Nguyen', 'text': 'Quán vui, nước ok. Tối t4 vui', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xoRVMzRTFNbGs1ZDFCeFgwRjBZMFpxTmw5SlVIYxAB', 'publishAt': '2 days ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xoRVMzRTFNbGs1ZDFCeFgwRjBZMFpxTmw5SlVIYxAB!2m1!1s0x0:0x3571b60d02fd12af!3m1!1s2@1:CAIQACodChtycF9oOlhES3E1Mlk5d1BxX0F0Y0ZqNl9JUHc%7C0dB4dt6bz7I%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '110868685349360257722', 'reviewerUrl': 'https://www.google.com/maps/contrib/110868685349360257722?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': 'Fun shop, ok drinks. Fun Wednesday night', 'publishedAtDate': '2025-12-03T15:42:49.127Z', 'reviewImageUrls': [], 'originalLanguage': 'vi', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a-/ALV-UjUmKutt-TylIRo6mNBbUcHt74yHLcew9tjKJHx43eQ8a7bb2mFS_A=s1920-c-rp-mo-br100', 'translatedLanguage': 'en', 'reviewDetailedRating': {}, 'responseFromOwnerDate': '2025-12-04T09:43:34.000Z', 'responseFromOwnerText': 'Dạ cảm ơn chị nhiều ạ', 'reviewerNumberOfReviews': 4}, {'name': 'Xuan Nam', 'text': 'nhà nhỏ xíu, phía trước là ngoài trời, trong nhà có máy lạnh mà tối, sida', 'stars': 2, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2pSVmJVcEVjMGRTVjJOc1dGVlBSVlF4YWpoQ2NFRRAB', 'publishAt': '2 days ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2pSVmJVcEVjMGRTVjJOc1dGVlBSVlF4YWpoQ2NFRRAB!2m1!1s0x0:0x3571b60d02fd12af!3m1!1s2@1:CAIQACodChtycF9oOjRVbUpEc0dSV2NsWFVPRVQxajhCcEE%7C0dAuZNRpmGn%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '108483542791555855381', 'reviewerUrl': 'https://www.google.com/m ...
# RealDictRow([('id', '1d66bcc3-7f32-42b6-8880-236437496c89'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 44, 552810)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 50, 48, 291000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"Art Bar Viet Nam","placeId":"ChIJoxiuV8wndTER8oq-i7-6Mr4","description":"","lat":10.8039632,"long":106.7290573,"type":["Bar","Art gallery","Cocktail bar"],"address":"29 Nguyễn Bá Huân, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/07c10978-ff43-4647-951b-5dc9c60acc97.jpg","photoUrls":["pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/07c10978-ff43-4647-951b-5dc9c60acc97.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/0895ab15-9491-4412-95b4-6f587f255f2c.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/0a4b4ab8-4137-4592-bbe9-4781eba17f36.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/3b624eff-248a-4e46-8d91-2f62fd729e13.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/3e9c630f-e107-4002-8911-9e83b081fa05.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/4dcffb55-3268-41cb-9321-f4537523a068.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/4fbdd9e2-76fa-4606-ac77-ea8bf8034081.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/5bee81d2-d737-4cb7-8053-b5e99173c695.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/7758a4a3-8c88-4374-9bbf-66987bd2e5e1.jpg","pois/images/ChIJoxiuV8wndTER8oq-i7-6Mr4/8ce78204-834b-40c2-9ae2-0752bd1feaf0.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '13705221947887880946', 'fid': '0x317527cc57ae18a3:0xbe32babf8bbe8af2', 'url': 'https://www.google.com/maps/search/?api=1&query=Art%20Bar%20Viet%20Nam&query_place_id=ChIJoxiuV8wndTER8oq-i7-6Mr4', 'city': 'Ho Chi Minh City', 'menu': 'https://www.facebook.com/photo.php?fbid=122126854790090513&set=pb.61552715402214.-2207520000&type=3', 'rank': 29, 'depth': 0, 'kgmid': '/g/11mqdfnj3n', 'phone': '+84 908 796 000', 'price': '₫200–300K', 'state': 'Quận 2, Ho Chi Minh City', 'title': 'Art Bar Viet Nam', 'domain': 'nhandan.vn', 'emails': ['nhandandientu@nhandan.vn', 'nhandantiengtrung@nhandan.vn', 'nhandanonline@nhandan.vn', 'nhandanenligne@nhandan.vn'], 'images': None, 'phones': ['+842439382413'], 'street': '29 Nguyễn Bá Huân', 'address': '29 Nguyễn Bá Huân, Thảo Điền, Quận 2, Thành phố Hồ Chí Minh, Vietnam', 'orderBy': [{'name': 'zalo.me', 'orderUrl': 'https://zalo.me/0908796000'}, {'name': 'facebook.com', 'orderUrl': 'https://www.facebook.com/ArtBarVietNam'}], 'placeId': 'ChIJoxiuV8wndTER8oq-i7-6Mr4', 'reddits': [], 'reviews': [{'name': 'Momo Paton', 'text': "Great place if you enjoy art and cocktails, and don't want to listen to basic English pop. Thank you for the awesome service and cocktails 👌👌👌", 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xWSE1IVkVOMmxyVWs5VGFYTnJTWFF4YzNZMGFVRRAB', 'publishAt': 'a day ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xWSE1IVkVOMmxyVWs5VGFYTnJTWFF4YzNZMGFVRRAB!2m1!1s0x0:0xbe32babf8bbe8af2!3m1!1s2@1:CAIQACodChtycF9oOlVHMHVEN2lrUk9TaXNrSXQxc3Y0aUE%7C0dBNuQ8p-ml%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '112888223831495737979', 'reviewerUrl': 'https://www.google.com/maps/contrib/112888223831495737979?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {'Wait time': 'No wait', 'Group size': '3-4 people', 'Seating type': 'Bar area', 'Price per person': '₫400–500K', 'Wheelchair accessibility': 'For Vietnam, it is very wheelchair accessible'}, 'textTranslated': None, 'publishedAtDate': '2025-12-04T13:37:31.164Z', 'reviewImageUrls': [], 'originalLanguage': 'en', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a-/ALV-UjUrFoDTKXQgdW7ziuMQd1PJ5E4bri4qv63lDD2Deln-geKDulfZOA=s1920-c-rp-mo-br100', 'translatedLanguage': None, 'reviewDetailedRating': {'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'review ...
# RealDictRow([('id', '144c2596-83cc-43b1-9436-98cf19b15f4e'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 45, 235161)), ('updatedAt', datetime.datetime(2025, 12, 6, 3, 43, 45, 235161)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"Ngỡ Cafe | Cà phê view đẹp Thủ Đức | Coffee ngon Hiệp Bình Phước","placeId":"ChIJF0ks3mUpdTERPOx40nmQtOA","description":"","lat":10.8487013,"long":106.7224209,"type":["Coffee shop"],"address":"08 Đường số 8, Hiệp Bình Phước, Thủ Đức, Thành phố Hồ Chí Minh, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/67275f7d-a8ad-4904-9531-f158b8d53a62.jpg","photoUrls":["pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/67275f7d-a8ad-4904-9531-f158b8d53a62.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/67eb7b28-1660-42e8-944b-aacacbe05866.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/6e2ccd6b-0840-431d-b2b5-2dac567646ac.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/930742ad-8db5-4cba-8b51-aafeb76f94cb.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/9fcae78a-3a98-4ccf-9360-51d3e66b6470.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/a11cdb78-5d53-4df3-896c-2ea585ffc948.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/bc3e176b-272c-4153-bb44-6835cc3dace4.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/c7a4b374-69af-4cd6-9c1b-90fff571b16a.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/c9e86951-c801-4eb7-9a4f-0f771d35b35e.jpg","pois/images/ChIJF0ks3mUpdTERPOx40nmQtOA/df8e08cc-9426-44e2-9721-84ba54b68986.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '16191725413200358460', 'fid': '0x31752965de2c4917:0xe0b49079d278ec3c', 'url': 'https://www.google.com/maps/search/?api=1&query=Ng%E1%BB%A1%20Cafe%20%7C%20C%C3%A0%20ph%C3%AA%20view%20%C4%91%E1%BA%B9p%20Th%E1%BB%A7%20%C4%90%E1%BB%A9c%20%7C%20Coffee%20ngon%20Hi%E1%BB%87p%20B%C3%ACnh%20Ph%C6%B0%E1%BB%9Bc&query_place_id=ChIJF0ks3mUpdTERPOx40nmQtOA', 'city': 'Ho Chi Minh City', 'menu': None, 'rank': 1, 'kgmid': '/g/11td41c7ck', 'phone': '+84 902 452 922', 'price': '₫1–100,000', 'state': 'Thủ Đức City, Ho Chi Minh City', 'title': 'Ngỡ Cafe | Cà phê view đẹp Thủ Đức | Coffee ngon Hiệp Bình Phước', 'emails': [], 'images': None, 'phones': [], 'street': '08 Đường số 8', 'address': '08 Đường số 8, Hiệp Bình Phước, Thủ Đức, Thành phố Hồ Chí Minh, Vietnam', 'orderBy': [], 'placeId': 'ChIJF0ks3mUpdTERPOx40nmQtOA', 'reviews': [{'name': 'Hoa Tran', 'text': None, 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2tkalYwcG5OSGh6T1VGRmMzSnlObkppVDFGTmFsRRAB', 'publishAt': '21 hours ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2tkalYwcG5OSGh6T1VGRmMzSnlObkppVDFGTmFsRRAB!2m1!1s0x0:0xe0b49079d278ec3c!3m1!1s2@1:CAIQACodChtycF9oOkdjV0pnNHhzOUFFc3JyNnJiT1FNalE%7C0dBI0UgcKK6%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '115332592448629788395', 'reviewerUrl': 'https://www.google.com/maps/contrib/115332592448629788395?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': None, 'publishedAtDate': '2025-12-04T06:55:27.748Z', 'reviewImageUrls': [], 'originalLanguage': None, 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a/ACg8ocJHmPKYOkeG_zqX6nojXds3N1yvXkVmGUTakZm9pTS8qyl4JA=s1920-c-rp-mo-br100', 'translatedLanguage': None, 'reviewDetailedRating': {'Food': 5, 'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'reviewerNumberOfReviews': 0}, {'name': 'Phương Hoàng', 'text': None, 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2tzNVJYSlFkVEJ2VjFSR2RGUmxSMGxpZVRSaU5IYxAB', 'publishAt': '5 days ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2tzNVJYSlFkVEJ2VjFSR2RGUmxSMGxpZVRSaU5IYxAB!2m1!1s0x0:0xe0b49079d278ec3c!3m1!1s2@1:CAIQACodChtycF9oOks5RXJQdTBvV1RGdFRlR0lieTRiNHc%7C0d9cNLNr7rZ%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId' ...
# RealDictRow([('id', '50510328-def5-497c-9ff6-c87eceb1d31a'), ('created_at', datetime.datetime(2025, 12, 6, 3, 43, 45, 581144)), ('updatedAt', datetime.datetime(2025, 12, 6, 10, 44, 40, 554000)), ('deletedAt', None), ('cityId', '3002ffe3-7c9e-4091-85da-819452858810'), ('source', 'GoogleMaps'), ('content', '{"name":"TEEMAY COFFEE ROASTERS","placeId":"ChIJZ6m1awAndTERtwMNyjOiZTY","description":"","lat":10.8168497,"long":106.7284654,"type":["Coffee shop"],"address":"187 Nguyễn Văn Hưởng, Phường An Khánh, Thủ Đức, Thành phố Hồ Chí Minh 700000, Vietnam","city":"Ho Chi Minh City","imageUrl":"pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/07b3820a-704f-4dea-80dd-2444c034d8b9.jpg","photoUrls":["pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/07b3820a-704f-4dea-80dd-2444c034d8b9.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/134168e4-f426-4adc-b20d-3ba38f0f5a61.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/134e5727-9019-455a-bb30-f789afe855df.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/2346bf2a-71f8-4462-9be5-cb8b82753820.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/92f822af-dff6-4549-98f5-24b32fae3e20.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/a850a9bb-d07c-4695-b40d-449e2e2535b8.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/aadc9309-ab93-4c71-8058-3bd566a87f6e.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/c9dd909b-c144-4643-a7f1-a61efdacd4cd.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/dd56c7db-1537-4885-950b-87691e39d666.jpg","pois/images/ChIJZ6m1awAndTERtwMNyjOiZTY/f86be75a-42ea-4de7-b902-ad5e517b6d0a.jpg"],"story":""}'), ('raw_data', {'google': {'cid': '3919717394012767159', 'fid': '0x317527006bb5a967:0x3665a233ca0d03b7', 'url': 'https://www.google.com/maps/search/?api=1&query=TEEMAY%20COFFEE%20ROASTERS&query_place_id=ChIJZ6m1awAndTERtwMNyjOiZTY', 'city': 'Ho Chi Minh City', 'menu': None, 'rank': 2, 'depth': 0, 'kgmid': '/g/11ybk7m8fy', 'phone': '+84 901 189 007', 'price': '₫1–100,000', 'state': 'Thủ Đức City, Ho Chi Minh City', 'title': 'TEEMAY COFFEE ROASTERS', 'domain': 'teemaycoffee.com', 'emails': ['teemaycoffee@gmail.com'], 'images': None, 'phones': [], 'street': '187 Nguyễn Văn Hưởng', 'address': '187 Nguyễn Văn Hưởng, Phường An Khánh, Thủ Đức, Thành phố Hồ Chí Minh 700000, Vietnam', 'orderBy': [], 'placeId': 'ChIJZ6m1awAndTERtwMNyjOiZTY', 'reddits': [], 'reviews': [{'name': 'Anh Nguyễn tuan', 'text': 'The serving size is fair, not too small, and reasonably priced for the quality', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xoV2VuVnRYMGxDVUZsbmRIWlVVMlV4YUhwRVdWRRAB', 'publishAt': '22 hours ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xoV2VuVnRYMGxDVUZsbmRIWlVVMlV4YUhwRVdWRRAB!2m1!1s0x0:0x3665a233ca0d03b7!3m1!1s2@1:CAIQACodChtycF9oOlhWenVtX0lCUFlndHZUU2UxaHpEWVE%7C0dB_pXNWVjW%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '103142154357294457567', 'reviewerUrl': 'https://www.google.com/maps/contrib/103142154357294457567?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'reviewContext': {}, 'textTranslated': None, 'publishedAtDate': '2025-12-05T04:19:46.411Z', 'reviewImageUrls': [], 'originalLanguage': 'en', 'reviewerPhotoUrl': 'https://lh3.googleusercontent.com/a/ACg8ocIUJPyTHdmuPi9V_4xmTbVTlHMdvtxlQUMKSahYTs2oyjLG8w=s1920-c-rp-mo-br100', 'translatedLanguage': None, 'reviewDetailedRating': {'Food': 5, 'Service': 5, 'Atmosphere': 5}, 'responseFromOwnerDate': None, 'responseFromOwnerText': None, 'reviewerNumberOfReviews': 0}, {'name': 'Ngocanh Tran', 'text': 'They play good music — light, instrumental, and easy on the ears', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xkV05VczNNMmhyVVZRd05FWmlhMEZ3TlZwNWNGRRAB', 'publishAt': '22 hours ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xkV05VczNNMmhyVVZRd05FWmlhMEZ3TlZwNWNGRRAB!2m1!1s0x0:0x3665a233ca0d03b7!3m1!1s2@1:CAIQACodChtycF9oOldWNUs3M2hrUVQwNEZia0FwNVp5cFE%7C0dB_XBhGmXH%7C?hl=en', 'visitedIn': None ...
# RealDictRow([('id', '5f1958f0-3c70-44e6-9ff0-a758909c28f5'), ('created_at', datetime.datetime(2025, 9, 27, 12, 46, 56, 454474)), ('updatedAt', datetime.datetime(2025, 12, 2, 11, 50, 35, 435000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.6985057,"city":"Málaga","long":-4.4368704,"name":"La Mafia se sienta a la mesa","type":["Italian restaurant","Bar & grill","Cocktail bar","Family restaurant","Northern Italian restaurant","Pizza delivery","Pizza restaurant","Pizza Takeout","Restaurant","Southern Italian restaurant"],"story":"Welcome to La Mafia se sienta a la mesa, a vibrant restaurant in Málaga that fuses Italian flavors with Andalusian charm! Did you know this spot is not just about delicious pasta and pizza? Opened in 2012, it quickly became a favorite, with over 200k followers on Instagram! Visitors rave about the cozy ambiance and friendly staff—perfect for a romantic dinner or a night out with friends. TikTok users are buzzing about their mouthwatering tiramisu, claiming it’s the best in town! So, as you savor each bite, remember you’re part of a culinary trend that celebrates both Italian heritage and Málaga\'s lively spirit! Enjoy!","address":"C/ Pacífico, 7, Carretera de Cádiz, 29004 Málaga, Spain","placeId":"ChIJldrwcyb5cg0RsfxIQZg-p8Y","imageUrl":"pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/7fdcd3cc-f5b0-4b4c-b78e-372516fda2f7.jpg","photoUrls":["pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/7fdcd3cc-f5b0-4b4c-b78e-372516fda2f7.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/36e9369d-7672-4ff8-96f9-e3f21ade598e.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/cf85c862-50b7-4276-8718-a3e4991227aa.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/02e9cfa9-d63e-488f-9411-6d5fc2922211.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/58411b5a-b14e-4c0b-bf65-2b0527be9eef.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/b51c358a-c85d-4d0a-aa6b-79e5b6e33dad.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/c0ca15cb-356f-4163-ab9d-78f1da216b24.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/e967ca28-8dac-481a-a2f2-89bea410c87b.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/1cf8b2b6-752a-4d5c-a86e-88bd5eda0ee2.jpg","pois/images/ChIJldrwcyb5cg0RsfxIQZg-p8Y/2870ea3a-383f-481c-9f64-d3abacbedbf2.jpg"],"description":"Discover the culinary gem, La Mafia se sienta a la mesa, nestled at C/ Pacífico, 7 in the vibrant Carretera de Cádiz, Málaga. This delightful restaurant captures the essence of Northern and Southern Italian cuisine, offering a menu brimming with mouthwatering pizzas, hearty pastas, and delectable grilled dishes. With its warm, inviting atmosphere, adorned with rustic decor, it’s the perfect spot for families and friends alike. Enjoy expertly crafted cocktails at the bar or indulge in a cozy dinner while soaking in the lively ambiance. Don’t miss the chance to experience this taste of Italy right in Málaga—come savor the flavors today!"}'), ('raw_data', {'google': {'cid': '14314478764271664305', 'fid': '0xd72f92673f0da95:0xc6a73e984148fcb1', 'url': 'https://www.google.com/maps/search/?api=1&query=La%20Mafia%20se%20sienta%20a%20la%20mesa&query_place_id=ChIJldrwcyb5cg0RsfxIQZg-p8Y', 'city': 'Málaga', 'menu': 'https://lamafia.es/carta/', 'rank': 97, 'kgmid': '/g/11p56jptz1', 'phone': '+34 623 29 01 80', 'price': '€20–30', 'state': 'Málaga', 'title': 'La Mafia se sienta a la mesa', 'images': None, 'street': 'C/ Pacífico, 7', 'address': 'C/ Pacífico, 7, Carretera de Cádiz, 29004 Málaga, Spain', 'orderBy': [{'name': 'Glovo', 'orderUrl': 'https://glovoapp.com/es/es/malaga/la-mafia-se-sienta-a-la-mesa-2?utm_source=google&utm_medium=organic&utm_campaign=google_reserve_place_order_action'}, {'name': 'covermanager.com', 'orderUrl': 'https://www.covermanager.com/go/restaurante-lamafiasesientaalamesa/es'}, {'name': 'Just Eat', 'orderUrl': 'https://www.just-eat.es/restaurants-la-mafia-se-sienta-a-la-mesa-malaga-29004/menu?serviceType=delivery&utm_source=google&utm_medium=organic&utm_cam ...
# RealDictRow([('id', '96451ce8-09ec-4b42-89ea-82534456e189'), ('created_at', datetime.datetime(2025, 9, 27, 12, 50, 54, 33985)), ('updatedAt', datetime.datetime(2025, 12, 2, 11, 45, 40, 110000)), ('deletedAt', None), ('cityId', 'e9455e0d-8805-47a7-9c44-96406551f1ca'), ('source', 'GoogleMaps'), ('content', '{"lat":36.721288,"city":"Málaga","long":-4.4198423,"name":"Bar tocata","type":["Disco club","Bar","Night club"],"story":"Welcome to the enchanting POI Bar Tocata, nestled in the vibrant heart of Málaga! Here, where centuries of history meet modern flair, you can sip on local wines while surrounded by stunning mosaics that echo Málaga\'s rich Moorish past. Did you know that this city once served as a vital harbor for the Phoenicians and Romans? Today, TikTok users rave about the bar’s signature tapas, tagging it as a must-try spot in their foodie adventures. With its lively atmosphere and soulful music, Tocata is not just a bar; it\'s a celebration of Málaga’s spirit. Cheers to history and flavor in every bite!","address":"C. Duque de la Victoria, 6, Distrito Centro, 29015 Málaga, Spain","placeId":"ChIJ8YqyY5X3cg0RrXGy9r5Ffhg","imageUrl":"pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/d74ff8d8-318b-4fe3-8e5d-a731a688716f.jpg","photoUrls":["pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/d74ff8d8-318b-4fe3-8e5d-a731a688716f.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/b5031ca3-3f60-42c3-ace4-3c77205bb929.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/bec593de-b2c1-4192-a9c6-87ecea4ba8e1.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/4601eba8-1bba-4ca3-a8e0-844bdfb4bc81.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/b91cafba-58c8-4f3e-9311-d0b9c3008d1b.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/a7a5bf9c-8232-490c-84d7-5906e584a0a5.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/403a446d-29d2-4bce-913c-391f63c96f5e.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/e5139512-d87f-4b14-b9ef-8d077b67b61c.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/42edf80f-80fa-486c-a1c3-8e1643203649.jpg","pois/images/ChIJ8YqyY5X3cg0RrXGy9r5Ffhg/38e03a54-4219-4e1e-af69-972f25c50fd3.jpg"],"description":"Nestled in the vibrant heart of Málaga, Bar Tocatá at C. Duque de la Victoria, 6, is a must-visit hotspot for night owls and music lovers alike. This lively disco club and bar pulses with energy, offering an eclectic mix of beats that will have you dancing until dawn. With its stylish decor and welcoming atmosphere, Bar Tocatá is the perfect place to unwind with friends or make new ones. Enjoy expertly crafted cocktails and immerse yourself in the local nightlife, where every night feels like a celebration. Come experience the magic of Málaga after dark!"}'), ('raw_data', {'google': {'cid': '1764924790460805549', 'fid': '0xd72f79563b28af1:0x187e45bef6b271ad', 'url': 'https://www.google.com/maps/search/?api=1&query=Bar%20tocata&query_place_id=ChIJ8YqyY5X3cg0RrXGy9r5Ffhg', 'city': 'Málaga', 'menu': None, 'rank': 16, 'kgmid': '/g/11b7l4k4p5', 'phone': '+34 722 86 55 95', 'price': '€1–10', 'state': 'Málaga', 'title': 'Bar tocata', 'images': None, 'street': 'C. Duque de la Victoria, 6', 'address': 'C. Duque de la Victoria, 6, Distrito Centro, 29015 Málaga, Spain', 'orderBy': [], 'placeId': 'ChIJ8YqyY5X3cg0RrXGy9r5Ffhg', 'reviews': [{'name': 'Víctor Peinado González', 'text': 'Perfect place to enjoy the night! It was amazing… people, music. We will go again 100%. Thanks for the service', 'stars': 5, 'rating': None, 'reviewId': 'Ci9DQUlRQUNvZENodHljRjlvT2xCNlQyUkNUa3d5VkVod1dub3pTMGxsYUZaWmNWRRAB', 'publishAt': '2 months ago', 'reviewUrl': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sCi9DQUlRQUNvZENodHljRjlvT2xCNlQyUkNUa3d5VkVod1dub3pTMGxsYUZaWmNWRRAB!2m1!1s0x0:0x187e45bef6b271ad!3m1!1s2@1:CAIQACodChtycF9oOlB6T2RCTkwyVEhwWnozS0llaFZZcVE%7C%7C?hl=en', 'visitedIn': None, 'likesCount': 0, 'reviewerId': '111342596225375141547', 'reviewerUrl': 'https://www.google.com/maps/contrib/111342596225375141547?hl=en', 'isLocalGuide': False, 'reviewOrigin': 'Google', 'review ...

# %% [markdown]
# # Các feature cần phải lấy ra từ table Poi

# %%
# id UUID PRIMARY KEY, lấy từ cột id
# name TEXT NOT NULL, lấy từ cột content
# address TEXT, lấy từ cột content 
# lat DOUBLE PRECISION NOT NULL, lấy từ cột content
# lon DOUBLE PRECISION NOT NULL, lấy từ cột content 
# geom GEOMETRY(Point, 4326) NOT NULL, tạo ra code
# poi_type TEXT, lấy từ cột content 
# stay_time DOUBLE PRECISION CHECK (stay_time >= 0), default 30
# avg_stars DOUBLE PRECISION CHECK (avg_stars BETWEEN 0 AND 5), lấy từ cột raw_data
# total_reviews INTEGER CHECK (total_reviews >= 0), từ cột raw_data
# normalize_stars_reviews DOUBLE PRECISION # normalize avg_stars và total_reviews về thang điểm 0-1

# %% [markdown]
# # Tạo 1 file csv

# %%
file_path = os.path.join(os.getcwd(), "data/data.csv")
print(f"File path: {file_path}")

# Tạo thư mục nếu chưa tồn tại
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# Tạo file nếu chưa tồn tại
if not os.path.exists(file_path):
    with open(file_path, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)

# Đọc dữ liệu
if not os.path.exists(file_path) or os.stat(file_path).st_size == 0:
    df = pd.DataFrame()   # df rỗng, chưa có cột
else:
    df = pd.read_csv(file_path)

print(df)
# Out:
# File path: /Users/macbook/Desktop/Kyanon/Kyanon-support-localtion/scripts/data/data.csv
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Trích xuất các trường

# %%
# id
id = []
cur.execute('SELECT id FROM "Poi"')
rows = cur.fetchall()
for poi in rows:
    id.append(poi['id'])
df["id"] = id

# %%
import json

name = []
address = []
lat = []
lon = []
poi_type = []

cur.execute('SELECT content FROM "Poi"')
rows = cur.fetchall()

for poi in rows:
    raw = poi.get("content")

    if not isinstance(raw, str):
        continue

    try:
        content = json.loads(raw)  # prase_json
    except Exception as e:
        print("Invalid JSON:", raw)
        continue

    name.append(content.get("name"))
    address.append(content.get("address"))
    lat.append(content.get("lat"))
    lon.append(content.get("long"))
    types = content.get("type")
    if isinstance(types, list):
        poi_type.append(",".join(types))
    else:
        poi_type.append(types)

df["name"] = name
df["address"] = address
df["lat"] = lat
df["lon"] = lon
df["poi_type"] = poi_type

# %%
# avg_stars và total_reviews từ raw_data
avg_stars = []
total_reviews = []
cur.execute('SELECT raw_data FROM "Poi"')
rows = cur.fetchall()
for poi in rows:
    raw_data = poi.get("raw_data")
    google = raw_data.get("google")
    avg_stars.append(google.get("totalScore"))
    total_reviews.append(google.get("reviewsCount"))
df["avg_stars"] = avg_stars
df["total_reviews"] = total_reviews

# %% [markdown]
# # Xuất vào csv

# %%
# Kiểm tra dữ liệu hiện tại của avg_stars và total_reviews
print("Kiểm tra dữ liệu avg_stars và total_reviews:")
print(f"Kiểu dữ liệu avg_stars: {df['avg_stars'].dtype}")
print(f"Kiểu dữ liệu total_reviews: {df['total_reviews'].dtype}")
print(f"Số lượng giá trị null trong avg_stars: {df['avg_stars'].isna().sum()}")
print(f"Số lượng giá trị null trong total_reviews: {df['total_reviews'].isna().sum()}")
print(f"\nMẫu dữ liệu:")
print(df[['name', 'avg_stars', 'total_reviews']].head(15))
print(f"\nCác giá trị unique của avg_stars: {df['avg_stars'].unique()[:20]}")
print(f"\nCác giá trị unique của total_reviews: {df['total_reviews'].unique()[:20]}")
# Out:
# Kiểm tra dữ liệu avg_stars và total_reviews:
# Kiểu dữ liệu avg_stars: object
# Kiểu dữ liệu total_reviews: object
# Số lượng giá trị null trong avg_stars: 2
# Số lượng giá trị null trong total_reviews: 0
#
# Mẫu dữ liệu:
#                                                  name avg_stars total_reviews
# 0                    The Pub Coffee - Beer & Cocktail       4.9           181
# 1                                             Julieta       4.3          2053
# 2                  BAIETA Restaurant Saigon Thao Dien       4.5           285
# 3                           Parroquia San Felipe Neri       4.7           329
# 4                                              BÀ BAR       4.8           182
# 5                                    Art Bar Viet Nam       4.9           165
# 6   Ngỡ Cafe | Cà phê view đẹp Thủ Đức | Coffee ng...       4.7           216
# 7                              TEEMAY COFFEE ROASTERS         5           275
# 8                        La Mafia se sienta a la mesa       4.3          1322
# 9                                          Bar tocata         4          1321
# 10                           BiaCraft Xuan Thuy | D.2       4.6          1624
# 11                         K-CITY (Korean Cafe & Bar)       4.7            15
# 12                                       Canalis Club       4.4          1637
# 13                 LOGAN STATION - The Gentlemen Café       4.6           352
# 14                                     Gét Gô Rooftop       4.7           166
#
# Các giá trị unique của avg_stars: [4.9 4.3 4.5 4.7 4.8 5 4 4.6 4.4 4.1 4.2 '5' 3.9 3.5 3.6 3.8 None 3.4 3.7
#  3.1]
#
# Các giá trị unique của total_reviews: [181 2053 285 329 182 165 216 275 1322 1321 1624 15 1637 352 166 1450 1393
#  2161 8 83]

# %%
# Xử lý avg_stars và total_reviews theo yêu cầu
# Nếu avg_stars hoặc total_reviews không có giá trị hoặc 1 trong 2 có giá trị 0
# thì cả 2 trường sẽ được đưa về giá trị thấp nhất

# Chuyển đổi sang numeric, các giá trị không hợp lệ sẽ thành NaN
df['avg_stars'] = pd.to_numeric(df['avg_stars'], errors='coerce')
df['total_reviews'] = pd.to_numeric(df['total_reviews'], errors='coerce')

# Tìm giá trị thấp nhất của mỗi cột (không tính null và 0)
min_avg_stars = df[(df['avg_stars'].notna()) & (df['avg_stars'] > 0)]['avg_stars'].min()
min_total_reviews = df[(df['total_reviews'].notna()) & (df['total_reviews'] > 0)]['total_reviews'].min()

print(f"Giá trị thấp nhất của avg_stars (không tính null và 0): {min_avg_stars}")
print(f"Giá trị thấp nhất của total_reviews (không tính null và 0): {min_total_reviews}")

# Tạo mask để xác định các hàng cần cập nhật
# Điều kiện: avg_stars hoặc total_reviews là null, hoặc 1 trong 2 bằng 0
mask = (
    df['avg_stars'].isna() | 
    df['total_reviews'].isna() | 
    (df['avg_stars'] == 0) | 
    (df['total_reviews'] == 0)
)

print(f"\nSố lượng hàng cần cập nhật: {mask.sum()}")
print(f"Trước khi cập nhật:")
print(df[mask][['name', 'avg_stars', 'total_reviews']].head(15))

# Cập nhật cả 2 cột về giá trị thấp nhất
df.loc[mask, 'avg_stars'] = min_avg_stars
df.loc[mask, 'total_reviews'] = min_total_reviews

print(f"\nSau khi cập nhật:")
print(df[mask][['name', 'avg_stars', 'total_reviews']].head(15))

print(f"\nKiểm tra lại:")
print(f"Số lượng giá trị null trong avg_stars: {df['avg_stars'].isna().sum()}")
print(f"Số lượng giá trị null trong total_reviews: {df['total_reviews'].isna().sum()}")
print(f"Số lượng giá trị 0 trong avg_stars: {(df['avg_stars'] == 0).sum()}")
print(f"Số lượng giá trị 0 trong total_reviews: {(df['total_reviews'] == 0).sum()}")
# Out:
# Giá trị thấp nhất của avg_stars (không tính null và 0): 3.0
# Giá trị thấp nhất của total_reviews (không tính null và 0): 1
#
# Số lượng hàng cần cập nhật: 10
# Trước khi cập nhật:
#                                                    name  avg_stars  \
# 255                                Co.opmart Chu Van An        4.1
# 257                        PICKLEBALL COLEGIO LA COLINA        NaN
# 308                         GOPICK - 250 Lương Định Của        4.6
# 597                            Tân Định Catholic Church        4.4
# 681                      Nhim Sau Rieng Gelato & Coffee        4.8
# 716                             Café Slow in the Garden        4.8
# 746                                        Chợ Hạt Điều        4.2
# 827                                        Ăn Vặt Bé Bơ        5.0
# 877   BIA HƠI HÀ NỘI ĐẠI VIỆT | QUÁN BIA HƠI QUẬN 12...        3.8
# 1452                                    parque infantil        NaN
#
#       total_reviews
# 255               0
# 257               0
# 308               0
# 597               0
# 681               0
# 716               0
# 746               0
# 827               0
# 877               0
# 1452              0
#
# Sau khi cập nhật:
#                                                    name  avg_stars  \
# 255                                Co.opmart Chu Van An        3.0
# 257                        PICKLEBALL COLEGIO LA COLINA        3.0
# 308                         GOPICK - 250 Lương Định Của        3.0
# 597                            Tân Định Catholic Church        3.0
# 681                      Nhim Sau Rieng Gelato & Coffee        3.0
# 716                             Café Slow in the Garden        3.0
# 746                                        Chợ Hạt Điều        3.0
# 827                                        Ăn Vặt Bé Bơ        3.0
# 877   BIA HƠI HÀ NỘI ĐẠI VIỆT | QUÁN BIA HƠI QUẬN 12...        3.0
# 1452                                    parque infantil        3.0
#
#       total_reviews
# 255               1
# 257               1
# 308               1
# 597               1
# 681               1
# 716               1
# 746               1
# 827               1
# 877               1
# 1452              1
#
# Kiểm tra lại:
# Số lượng giá trị null trong avg_stars: 0
# Số lượng giá trị null trong total_reviews: 0
# Số lượng giá trị 0 trong avg_stars: 0
# Số lượng giá trị 0 trong total_reviews: 0

# %%
df.to_csv(file_path, index=False)
